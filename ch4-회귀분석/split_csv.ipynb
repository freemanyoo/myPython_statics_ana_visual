# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
split_csv.py
- 큰 CSV를 행 단위 청크로 분할 저장
- recipe_code 컬럼 기준으로도 별도 분할 저장
- 한글/Excel 호환 위해 UTF-8-SIG로 저장
"""

import os
import pandas as pd

# 설정값
input_path = "Recipe Reviews and User Feedback Dataset.csv"           # 원본 CSV 경로
out_dir_rows = "out_rows"          # 행 단위 분할 출력 폴더
out_dir_group = "out_by_recipe"    # recipe_code별 분할 출력 폴더
rows_per_file = 10000              # 파일당 행 수
encoding_in = "utf-8"              # 입력 인코딩 (필요시 변경)
encoding_out = "utf-8-sig"         # 출력 인코딩 (Excel 호환 우수)

def ensure_dir(path: str):
    if not os.path.exists(path):
        os.makedirs(path, exist_ok=True)

def split_by_rows():
    ensure_dir(out_dir_rows)
    print(f"[행 분할] {input_path} -> {out_dir_rows} (파일당 {rows_per_file}행)")
    i = 0
    for i, chunk in enumerate(pd.read_csv(input_path, chunksize=rows_per_file, encoding=encoding_in)):
        out_path = os.path.join(out_dir_rows, f"chunk_{i:03}.csv")
        chunk.to_csv(out_path, index=False, encoding=encoding_out)
        print(f"  - saved: {out_path} ({len(chunk)} rows)")
    if i == 0:
        print("  - 완료")

def split_by_recipe_code():
    ensure_dir(out_dir_group)
    print(f"[그룹 분할] recipe_code 기준 -> {out_dir_group}")
    # 메모리 여유가 있으면 전체 로드, 없으면 청크 기반으로 변경
    df = pd.read_csv(input_path, encoding=encoding_in)
    if "recipe_code" not in df.columns:
        raise KeyError("recipe_code 컬럼이 없습니다. 컬럼명을 확인하세요.")
    for key, g in df.groupby("recipe_code", dropna=False):
        safe_key = str(key).replace("/", "_").replace("\\", "_")
        out_path = os.path.join(out_dir_group, f"by_recipe_code_{safe_key}.csv")
        g.to_csv(out_path, index=False, encoding=encoding_out)
        print(f"  - saved: {out_path} ({len(g)} rows)")

if __name__ == "__main__":
    if not os.path.isfile(input_path):
        raise FileNotFoundError(f"입력 파일을 찾을 수 없습니다: {input_path}")
    split_by_rows()
    split_by_recipe_code()
    print("완료.")
# Out:
# [행 분할] Recipe Reviews and User Feedback Dataset.csv -> out_rows (파일당 10000행)
#   - saved: out_rows\chunk_000.csv (10000 rows)
#   - saved: out_rows\chunk_001.csv (8182 rows)
# [그룹 분할] recipe_code 기준 -> out_by_recipe
#   - saved: out_by_recipe\by_recipe_code_386.csv (224 rows)
#   - saved: out_by_recipe\by_recipe_code_414.csv (167 rows)
#   - saved: out_by_recipe\by_recipe_code_957.csv (211 rows)
#   - saved: out_by_recipe\by_recipe_code_1063.csv (158 rows)
#   - saved: out_by_recipe\by_recipe_code_1081.csv (148 rows)
#   - saved: out_by_recipe\by_recipe_code_1152.csv (157 rows)
#   - saved: out_by_recipe\by_recipe_code_1196.csv (172 rows)
#   - saved: out_by_recipe\by_recipe_code_1324.csv (136 rows)
#   - saved: out_by_recipe\by_recipe_code_1693.csv (232 rows)
#   - saved: out_by_recipe\by_recipe_code_1821.csv (90 rows)
#   - saved: out_by_recipe\by_recipe_code_2832.csv (725 rows)
#   - saved: out_by_recipe\by_recipe_code_2872.csv (222 rows)
#   - saved: out_by_recipe\by_recipe_code_2912.csv (332 rows)
#   - saved: out_by_recipe\by_recipe_code_3058.csv (194 rows)
#   - saved: out_by_recipe\by_recipe_code_3143.csv (159 rows)
#   - saved: out_by_recipe\by_recipe_code_3290.csv (109 rows)
#   - saved: out_by_recipe\by_recipe_code_3309.csv (509 rows)
#   - saved: out_by_recipe\by_recipe_code_3683.csv (86 rows)
#   - saved: out_by_recipe\by_recipe_code_4383.csv (145 rows)
#   - saved: out_by_recipe\by_recipe_code_4444.csv (131 rows)
#   - saved: out_by_recipe\by_recipe_code_6086.csv (241 rows)
#   - saved: out_by_recipe\by_recipe_code_6504.csv (221 rows)
#   - saved: out_by_recipe\by_recipe_code_7178.csv (269 rows)
#   - saved: out_by_recipe\by_recipe_code_7539.csv (141 rows)
#   - saved: out_by_recipe\by_recipe_code_7708.csv (204 rows)
#   - saved: out_by_recipe\by_recipe_code_7752.csv (107 rows)
#   - saved: out_by_recipe\by_recipe_code_8015.csv (96 rows)
#   - saved: out_by_recipe\by_recipe_code_8202.csv (125 rows)
#   - saved: out_by_recipe\by_recipe_code_8431.csv (164 rows)
#   - saved: out_by_recipe\by_recipe_code_9010.csv (144 rows)
#   - saved: out_by_recipe\by_recipe_code_9735.csv (105 rows)
#   - saved: out_by_recipe\by_recipe_code_9739.csv (161 rows)
#   - saved: out_by_recipe\by_recipe_code_10248.csv (130 rows)
#   - saved: out_by_recipe\by_recipe_code_10252.csv (254 rows)
#   - saved: out_by_recipe\by_recipe_code_11330.csv (112 rows)
#   - saved: out_by_recipe\by_recipe_code_11588.csv (131 rows)
#   - saved: out_by_recipe\by_recipe_code_11767.csv (128 rows)
#   - saved: out_by_recipe\by_recipe_code_12003.csv (276 rows)
#   - saved: out_by_recipe\by_recipe_code_12259.csv (129 rows)
#   - saved: out_by_recipe\by_recipe_code_12347.csv (144 rows)
#   - saved: out_by_recipe\by_recipe_code_12540.csv (368 rows)
#   - saved: out_by_recipe\by_recipe_code_12700.csv (173 rows)
#   - saved: out_by_recipe\by_recipe_code_12734.csv (194 rows)
#   - saved: out_by_recipe\by_recipe_code_14299.csv (654 rows)
#   - saved: out_by_recipe\by_recipe_code_14600.csv (186 rows)
#   - saved: out_by_recipe\by_recipe_code_15805.csv (128 rows)
#   - saved: out_by_recipe\by_recipe_code_16458.csv (135 rows)
#   - saved: out_by_recipe\by_recipe_code_16579.csv (137 rows)
#   - saved: out_by_recipe\by_recipe_code_17022.csv (31 rows)
#   - saved: out_by_recipe\by_recipe_code_17310.csv (154 rows)
#   - saved: out_by_recipe\by_recipe_code_17826.csv (338 rows)
#   - saved: out_by_recipe\by_recipe_code_18274.csv (144 rows)
#   - saved: out_by_recipe\by_recipe_code_18341.csv (96 rows)
#   - saved: out_by_recipe\by_recipe_code_18345.csv (164 rows)
#   - saved: out_by_recipe\by_recipe_code_19201.csv (152 rows)
#   - saved: out_by_recipe\by_recipe_code_19731.csv (324 rows)
#   - saved: out_by_recipe\by_recipe_code_20170.csv (146 rows)
#   - saved: out_by_recipe\by_recipe_code_21444.csv (395 rows)
#   - saved: out_by_recipe\by_recipe_code_23222.csv (152 rows)
#   - saved: out_by_recipe\by_recipe_code_24886.csv (133 rows)
#   - saved: out_by_recipe\by_recipe_code_26937.csv (148 rows)
#   - saved: out_by_recipe\by_recipe_code_27434.csv (156 rows)
#   - saved: out_by_recipe\by_recipe_code_27626.csv (138 rows)
#   - saved: out_by_recipe\by_recipe_code_27675.csv (96 rows)
#   - saved: out_by_recipe\by_recipe_code_27696.csv (164 rows)
#   - saved: out_by_recipe\by_recipe_code_28058.csv (179 rows)
#   - saved: out_by_recipe\by_recipe_code_31278.csv (149 rows)
#   - saved: out_by_recipe\by_recipe_code_32248.csv (128 rows)
#   - saved: out_by_recipe\by_recipe_code_32264.csv (99 rows)
#   - saved: out_by_recipe\by_recipe_code_32480.csv (397 rows)
#   - saved: out_by_recipe\by_recipe_code_32535.csv (178 rows)
#   - saved: out_by_recipe\by_recipe_code_33121.csv (120 rows)
#   - saved: out_by_recipe\by_recipe_code_33206.csv (187 rows)
#   - saved: out_by_recipe\by_recipe_code_33457.csv (138 rows)
#   - saved: out_by_recipe\by_recipe_code_33743.csv (125 rows)
#   - saved: out_by_recipe\by_recipe_code_34347.csv (86 rows)
#   - saved: out_by_recipe\by_recipe_code_35766.csv (100 rows)
#   - saved: out_by_recipe\by_recipe_code_35948.csv (175 rows)
#   - saved: out_by_recipe\by_recipe_code_36217.csv (116 rows)
#   - saved: out_by_recipe\by_recipe_code_36450.csv (226 rows)
#   - saved: out_by_recipe\by_recipe_code_38183.csv (130 rows)
#   - saved: out_by_recipe\by_recipe_code_38550.csv (133 rows)
#   - saved: out_by_recipe\by_recipe_code_39334.csv (127 rows)
#   - saved: out_by_recipe\by_recipe_code_39545.csv (133 rows)
#   - saved: out_by_recipe\by_recipe_code_39549.csv (174 rows)
#   - saved: out_by_recipe\by_recipe_code_39581.csv (134 rows)
#   - saved: out_by_recipe\by_recipe_code_41095.csv (149 rows)
#   - saved: out_by_recipe\by_recipe_code_41101.csv (268 rows)
#   - saved: out_by_recipe\by_recipe_code_41384.csv (162 rows)
#   - saved: out_by_recipe\by_recipe_code_42083.csv (421 rows)
#   - saved: out_by_recipe\by_recipe_code_42386.csv (197 rows)
#   - saved: out_by_recipe\by_recipe_code_42873.csv (110 rows)
#   - saved: out_by_recipe\by_recipe_code_43675.csv (191 rows)
#   - saved: out_by_recipe\by_recipe_code_45495.csv (171 rows)
#   - saved: out_by_recipe\by_recipe_code_46655.csv (128 rows)
#   - saved: out_by_recipe\by_recipe_code_74724.csv (147 rows)
#   - saved: out_by_recipe\by_recipe_code_82745.csv (119 rows)
#   - saved: out_by_recipe\by_recipe_code_100276.csv (164 rows)
#   - saved: out_by_recipe\by_recipe_code_141947.csv (114 rows)
#   - saved: out_by_recipe\by_recipe_code_191775.csv (112 rows)
# 완료.
