# %% [markdown]
# ## 한글 형태소 분석 ,시각화, 워드 클라우드 등.
# ### 형태소 분석, 품사 태깅.
# ### 데이터 : 샘플 데이터 , 페이스북 전자 신문에서 크롤링 한 임시 데이터로  대체
# ### 설치 가 조금 복잡함.
# ### 1) jdk 17 이상 2) JPype(자바, 파이썬 연결하는 도구) 3) konlpy 패키지 설치.
#
# ## 주의사항, JPype 버전 1.4,  파이썬 버전 3.10.7 다운그레이드
# ## 시스템 환경 변수 , ex) JAVA_HOME : 경로 추가 하기. jdk 17
# ### 변수명 : JAVA_HOME (동일하게)
# ### 시스템 환경 변수의 경로 값 예제: C:\Program Files\Java\jdk-17\bin
# ### 변수명 : Path
# ### 경로 : C:\Program Files\Java\jdk-17\bin
#
# ## 파이썬 3.10.x , 예) 3.10.7 버전으로 다운 받기.
# ### 시스템 환경 변수 추가 작업
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\
#
# ### 변수명 : Path
# ### 경로C:\Python\Python39\Scripts
#
# ### cmd -> python -V
#
# ## 2) JPype(자바, 파이썬 연결하는 도구)
# ### 다운로드 사이트 주소 : https://github.com/jpype-project/jpype/releases
# ### JPype 검색하고, 버전은 jpype1-1.6.0-cp313-cp313-win_amd64.whl 받아서,
# ### 해당 다운로드 받은 폴더 이동하고, 해당 폴더 검색경로에서, cmd 실행하고,
# ### cmd -> pip install jpype1-1.6.0-cp313-cp313-win_amd64.whl
# ### 업그레이드 경고창 뜨면 :
# ### python.exe -m pip install --upgrade pip
# ### 업그레이드 후 , 다시 설치
# ### pip install jpype1-1.6.0-cp313-cp313-win_amd64.whl
# ### , 명령어 붙여넣기.
# ### pip install konlpy
#
# ### 코드 실행시, 설치한(다운그레이드한 버전, 3.10.7) 선택,
# ### 해당 쥬피터 노트북 관련 커널 설치도 자동으로 함.

# %% [markdown]
# # 용어 정리
# ## 형태소 , 형태소 분석
# ### 형태소: 언어에서 의미가 가장 작은 단위.
# ### 형태소 분석: 형태소, 어근, 접두사/접미사, 품사 등 다양한 속성 구조.
# ### 품사 태깅 예) 상용 이가 좋아 하는 음식 은 국밥 이다.
# ### 음식 : NNG, 이가/JKM , 좋아하는/VV, 이다/EFN , 높임말 : 하신다 -> 신/EPH
# ### 품사 태깅 해주는 패키지 : Hananum, Kkma, Komoran, Okt(Twitter 제공)
# ### Okt , 명사 /Noun , 에/ Josa, 먹는/ Verb , 다/Eomi

# %% [markdown]
# # 샘플 데이터 사용.
# #

# %%
# 최초 실행 때는, 설치 후에 주석하기. 
# !pip install matplotlib
# !pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\it\appdata\roaming\python\python310\site-packages (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\it\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: wordcloud in c:\users\it\appdata\roaming\python\python310\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from wordcloud) (1.26.4)
# Requirement already satisfied: pillow in c:\users\it\appdata\roaming\python\python310\site-packages (from wordcloud) (10.4.0)
# Requirement already satisfied: matplotlib in c:\users\it\appdata\roaming\python\python310\site-packages (from wordcloud) (3.9.1.post1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\it\appdata\roaming\python\python310\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\it\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import json
import re 
# Okt , 한글 품사 태깅하기위한 모듈, 도구.
from konlpy.tag import Okt
from collections import Counter
import matplotlib
import matplotlib.pyplot as plt 
from matplotlib import font_manager, rc 
from wordcloud import WordCloud

# %%
# 샘플 데이터 읽어서, 메모리에서 확인해보기. 
# inputFileName = "./etnews.kr_facebook_2016-01-01_2018-08-01_4차 산업혁명.json"
inputFileName = "./트럼프_naver_news.json"
# inputFileName = "./부산서면맛집2_naver_news.json"
data = json.loads(open(inputFileName,"r",encoding = "utf-8").read())
data
# Out:
# [{'cnt': 1,
#   'description': '이 회사의 모회사인 애니플러스도 서울 합정동과 <b>부산 서면</b> 등에 일본 애니메이션과 협업해 굿즈를... 이은희 인하대 소비자학과 교수는 “돈키호테에서 이색적인 제품을 찾거나 일식 <b>맛집</b>을 발굴하는 등 색다르게... ',
#   'link': 'https://n.news.naver.com/mnews/article/015/0005158079?sid=101',
#   'org_link': 'https://www.hankyung.com/article/202507158979i',
#   'pDate': '2025-07-15 13:13:00',
#   'title': '&quot;일본 여행 온 것 같아요&quot; MZ들 우르르…한국인 일상 파고든 日'},
#  {'cnt': 2,
#   'description': "강남역 '일상비일상의틈'과 <b>부산 서면</b> '일상의틈' 매장에 중소기업 제품 판매 공간을 마련했다고 2일... 이용자가 원하는 조건의 장소를 대화형식으로 입력하면 개인의 취향과 라이프스타일에 맞는 <b>맛집</b>, 카페... ",
#   'link': 'https://dealsite.co.kr/articles/143995',
#   'org_link': 'https://dealsite.co.kr/articles/143995',
#   'pDate': '2025-07-02 15:10:00',
#   'title': "[재계는 지금] 인텔코리아 '2025 AI 서밋' 행사 성료 外"},
#  {'cnt': 3,
#   'description': "인근 <b>맛집</b>인 '이수가 본점'과 '카린지&amp;린가네 스낵바'와 협업한 상품을 선보인다. 기존 '강릉편(1탄)'과... 스타필드점 △<b>부산 서면</b>점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다. 이번 협업... ",
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=679327',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=679327',
#   'pDate': '2025-03-19 14:34:00',
#   'title': '[오늘의 장바구니] 홈플러스·쌤소나이트·한화호텔앤드리조트 외'},
#  {'cnt': 4,
#   'description': "스타필드점 ▲<b>부산 서면</b>점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다. 이번 협업... 인근 <b>맛집</b>인 '이수가 본점'과 '카린지&amp;린가네 스낵바'와 협업한 상품을 선보인다. 기존 '강릉편(1탄)'과 '충청도... ",
#   'link': 'http://www.popcornnews.net/news/articleView.html?idxno=75057',
#   'org_link': 'http://www.popcornnews.net/news/articleView.html?idxno=75057',
#   'pDate': '2025-03-19 13:52:00',
#   'title': "[POP!이벤트] LF '아떼' &amp; 뷰티크리에이터 '민스코' 최초 협업 네이버 쇼..."},
#  {'cnt': 5,
#   'description': "론칭 이후 팬츠 누적 판매량만 500만장에 달하는 등 '남성 팬츠 <b>맛집</b>' 브랜드로 익숙하다. 이번 다니엘... 스타필드점 ▲<b>부산 서면</b>점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다. 이번 협업... ",
#   'link': 'https://www.pressman.kr/news/articleView.html?idxno=87891',
#   'org_link': 'https://www.pressman.kr/news/articleView.html?idxno=87891',
#   'pDate': '2025-03-19 11:44:00',
#   'title': "[플맨픽-유통] CJ온스타일, '다니엘 크레뮤' 모델로 배우 이준혁 발탁 外"},
#  {'cnt': 6,
#   'description': '스타필드점, <b>부산 서면</b>점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다. 이번 협업... 커뮤니티 가입 회원들은 방문 후기, 백화점 이용 TIP, 인근 <b>맛집</b> 정보 등을 공유하며 신세계와 함께한 다양한 일상과... ',
#   'link': 'http://www.newswatch.kr/news/articleView.html?idxno=70944',
#   'org_link': 'http://www.newswatch.kr/news/articleView.html?idxno=70944',
#   'pDate': '2025-03-19 11:06:00',
#   'title': '[유통워치] 유통업계, 신제품 출시·이벤트·업무협약·착공·후원·트렌...'},
#  {'cnt': 7,
#   'description': '야당 일각에선 ‘지역 <b>맛집</b> 소개’ 계획이 세워진 것으로 알려져 찬반 여론이 대립했다. 16일... 같은 날 오후 4~6시 <b>부산 서면</b> 동천로 일대에서는 정권퇴진<b>부산</b>시민행동 주최로 ‘28차 정권 파면 시민대회’가 실시됐다.... ',
#   'link': 'https://m.skyedaily.com/news_view.html?ID=266259',
#   'org_link': 'https://m.skyedaily.com/news_view.html?ID=266259',
#   'pDate': '2025-03-16 13:50:00',
#   'title': '“尹대통령 선고 전 마지막 주말집회 되나” 여야 총력전'},
#  {'cnt': 8,
#   'description': '기존 판매했던 점포들에 서울 지역 3개점을 더했으며, <b>부산서면</b>중앙점에서도 해당 상품을 만나볼 수 있다.... 실력을 검증받은 유명 셰프를 비롯한 전국구 <b>맛집</b>과의 협업도 늘리고 있다. 실제로 쓱닷컴은 최근 △주서빈... ',
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=677880',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=677880',
#   'pDate': '2025-03-10 14:54:00',
#   'title': '[오늘의 장바구니] 홈플러스·이마트·아모레퍼시픽·워커힐 외'},
#  {'cnt': 9,
#   'description': '해외유학과 이민을 위한 IELTS(국제 영어 시험) 전문 교육 기관인 렉시스어학원이 서울 강남과 <b>부산 서면</b>에... 캠퍼스 건너편에는 다양한 <b>맛집</b>과 여유롭게 산책할 수 있는 연트럴파크가 자리 잡고 있어 홍대신촌... ',
#   'link': 'https://www.job-post.co.kr/news/articleView.html?idxno=125642',
#   'org_link': 'https://www.job-post.co.kr/news/articleView.html?idxno=125642',
#   'pDate': '2025-02-10 15:00:00',
#   'title': '아이엘츠 전문 렉시스어학원, 홍대신촌 캠퍼스 오픈'},
#  {'cnt': 10,
#   'description': '스시 고우 <b>서면</b>에 위치한 숨은 <b>맛집</b>으로, 가격 대비 높은 퀄리티의 오마카세를 제공한다. 합리적인 가격으로 고급 오마카세를 경험할 수 있으며, 런치 오마카세가 특히 인기 있다. 위치: <b>부산 서면</b> 추천 메뉴: 런치 오마카세... ',
#   'link': 'http://www.tournews21.com/news/articleView.html?idxno=85330',
#   'org_link': 'http://www.tournews21.com/news/articleView.html?idxno=85330',
#   'pDate': '2025-02-06 09:58:00',
#   'title': '<b>부산</b>, 미식가를 위한 오마카세 <b>맛집</b> BEST 5!'},
#  {'cnt': 11,
#   'description': '<b>부산 서면</b>은 다양한 놀거리와 핫플레이스가 모여 있는 대표적인 번화가다. 낮에는 쇼핑과 카페 투어를... 디저트 <b>맛집</b>도 많아 SNS에 업로드하기 좋은 사진을 남길 수 있다. <b>2</b>. <b>서면</b> 롯데백화점 &amp; 전자상가 쇼핑을 좋아하는... ',
#   'link': 'http://www.tournews21.com/news/articleView.html?idxno=85056',
#   'org_link': 'http://www.tournews21.com/news/articleView.html?idxno=85056',
#   'pDate': '2025-02-05 10:10:00',
#   'title': '<b>서면</b> 놀거리 BEST 5, <b>부산</b>의 핫플레이스를 한눈에!'},
#  {'cnt': 12,
#   'description': '입구 <b>맛집</b> ‘메밀씨앗호떡’ 등을 포함해 다양한 특산품을 대거 선보일 예정이다. 롯데몰 김해점은 신규... <b>부산</b>에서는 <b>서면</b>과 센텀시티에 이어 세 번째로 선보이는 매장으로, 프리미엄 수제 버거에 대한 관심이 높은... ',
#   'link': 'https://n.news.naver.com/mnews/article/082/0001309124?sid=101',
#   'org_link': 'https://www.busan.com/view/busan/view.php?code=2025012318135036840',
#   'pDate': '2025-01-23 18:15:00',
#   'title': '최장 9일 ‘황금 설 연휴’ 아웃렛은 ‘연중무휴’'},
#  {'cnt': 13,
#   'description': '<b>맛집</b> #전통방식 보양 미역국 대표 보양식 미역국은 생일을 기념해 먹는 음식이다. 칼슘과 아이오딘이 많아 피를 맑게 하고, 혈액순환을 촉진하는 헬스 푸드이자, 특별한 날 대접받는 듯한 느낌도 준다. 2015년 <b>부산 서면</b>에... ',
#   'link': 'https://n.news.naver.com/mnews/article/057/0001867331?sid=103',
#   'org_link': 'http://mbn.mk.co.kr/pages/news/newsView.php?category=mbn00007&news_seq_no=5088838',
#   'pDate': '2025-01-17 16:42:00',
#   'title': '“신년회 장소로 여기 어때?” 새해 첫 모임 식당 [Find Dining]'},
#  {'cnt': 14,
#   'description': '그래서 장아찌만 잘해도 그리 특별한 것 없는 백반집이 <b>맛집</b>으로 소문난다. 장아찌의 역할은 밥 먹기에 좋은... ◇ 팔미분식 = <b>부산 서면</b>의 밤낮을 오랜 시간 지켜온 집이다. 다양한 분식을 파는데 특히 충무김밥이 본향... ',
#   'link': 'https://n.news.naver.com/mnews/article/021/0002684419?sid=103',
#   'org_link': 'https://www.munhwa.com/news/view.html?no=2025011601032712000001',
#   'pDate': '2025-01-16 09:24:00',
#   'title': '오래도록 맛있도록… 새콤달콤 ‘절임의 미학’[이우석의 푸드로지]'},
#  {'cnt': 15,
#   'description': '<b>부산</b>에 자리한 여러 곳의 돼지국밥 <b>맛집</b>을 돌아다니며 다양한 돼지국밥을 맛보고 즐기는 것을 추천한다. <b>서면</b>향토음식특화거리. 송정3대국밥. 식당 정보 [송정3대국밥] 1946년 개업해 지금까지 <b>부산</b>의 대표 국밥... ',
#   'link': 'https://www.korea.kr/news/weekendView.do?newsId=148938382&call_from=naver_news',
#   'org_link': 'https://www.korea.kr/news/weekendView.do?newsId=148938382&call_from=naver_news',
#   'pDate': '2025-01-09 16:48:00',
#   'title': '[K-로컬 미식여행 33선] (9) <b>부산</b>을 대표하는 향토음식, 돼지국밥'},
#  {'cnt': 16,
#   'description': '현재 <b>부산</b> 최대 도심인 <b>부산</b>진구 <b>서면</b> 개발, 1998년 <b>부산</b>시 청사 이전 등으로 원도심은 쇠퇴를 시작했다.... 토론회에서는 관광객 이동 편의를 위해 원도심 관광셔틀버스 도입과 함께, 지역 명소와 <b>맛집</b>을 포함한 통합... ',
#   'link': 'https://n.news.naver.com/mnews/article/658/0000089396?sid=100',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0100&key=20241127.99099008196',
#   'pDate': '2024-11-27 15:07:00',
#   'title': '<b>부산</b>시의회 &quot;원도심 관광 환경 수준 높여야&quot;'},
#  {'cnt': 17,
#   'description': '현장상황관리관을 파견하는 12곳은 서울 이태원·홍대·명동·성수동·건대와 <b>부산 서면</b>, 대구 동성로, 대전... 연세로 △발산역 △문래동 <b>맛집</b>거리 △신림역 △샤로수길 △논현역 등 인파 밀집이 예상되는 서울 시내 15개... ',
#   'link': 'https://n.news.naver.com/mnews/article/421/0007864217?sid=102',
#   'org_link': 'https://www.news1.kr/local/seoul/5577293',
#   'pDate': '2024-10-24 05:10:00',
#   'title': "'제2의 이태원 참사' 막는다…정부·서울시, 안전관리 '총력'"},
#  {'cnt': 18,
#   'description': '연세로 ▲발산역 ▲문래동 <b>맛집</b>거리 ▲신림역 ▲샤로수길 ▲논현역 등 11개구 15곳이다. 시는 이들 지역을... 행안부는 인파밀집도가 높을 곳으로 예측되는 서울 이태원･홍대･명동･성수동･건대 등, <b>부산 서면</b>, 대구... ',
#   'link': 'https://www.m-economynews.com/news/article.html?no=47078',
#   'org_link': 'https://www.m-economynews.com/news/article.html?no=47078',
#   'pDate': '2024-10-23 16:18:00',
#   'title': '다시 돌아오는 핼러윈...서울시, 인파 밀집지역 15곳 집중관리'},
#  {'cnt': 19,
#   'description': '은하수 <b>맛집</b> 거리 참여 업체 27곳에서는 10% 할인 행사를 진행해 많은 호응을 얻었다. <b>부산</b>광역시 <b>부산</b>진구 소상공인연합회 관계자는 &quot;이번 축제를 통해 소상공인 간의 협력을 증진하고 <b>서면</b> 골목상권 활성화에 기여할 수... ',
#   'link': 'https://www.pointe.co.kr/news/articleView.html?idxno=30965',
#   'org_link': 'https://www.pointe.co.kr/news/articleView.html?idxno=30965',
#   'pDate': '2024-10-07 23:30:00',
#   'title': "'제2회 <b>서면</b> 골목상권 축제' 성황리 마무리…소상공인 경쟁력 강화"},
#  {'cnt': 20,
#   'description': '은하수 <b>맛집</b> 거리 참여 업체 27곳에서는 10% 할인 행사를 진행한다. <b>부산</b>광역시 <b>부산</b>진구 소상공인연합회 관계자는 &quot;이번 축제를 통해 소상공인 간의 연대감을 강화하고 <b>서면</b> 골목상권을 활성화할 것&quot;이라며 &quot;소상공인에게... ',
#   'link': 'https://www.pointe.co.kr/news/articleView.html?idxno=30651',
#   'org_link': 'https://www.pointe.co.kr/news/articleView.html?idxno=30651',
#   'pDate': '2024-09-27 21:36:00',
#   'title': "<b>부산</b>진구 소상공인연합회, <b>서면</b> 쌈지공원 일대서 '제2회 <b>서면</b> 골목상권..."},
#  {'cnt': 21,
#   'description': '펫프렌들리ㆍ뷰 <b>맛집</b>ㆍ스마트 오피스까지...다양한 콘셉트로 차별화 꾀해 코로나19 이후 수익성이 악화한... SPC가 운영하는 또 다른 카페 브랜드 파스쿠찌도 4월 <b>부산 서면</b>점과 광안리점에 젤라토 메뉴를 특화한 매장을... ',
#   'link': 'https://www.etoday.co.kr/news/view/2401584',
#   'org_link': 'https://www.etoday.co.kr/news/view/2401584',
#   'pDate': '2024-09-22 18:30:00',
#   'title': '칵테일 팔고 가전제품도 보고…여기 커피숍 맞나요'},
#  {'cnt': 22,
#   'description': '전국 라멘 <b>맛집</b>으로는 경기 분당 서현 유타로, 일산동구 계단라멘, 의정부 사쿠라멘, 수원 팔달구 키와마루아지, 안양 쿠시카츠 쿠마, 양산 무라, <b>부산 서면</b> 칸다소바, <b>부산</b> 해운대 나가하마만게츠, <b>부산 서면</b> 친치쿠린... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2176872',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2176872',
#   'pDate': '2024-09-14 00:05:00',
#   'title': '[안병익의 식신 <b>맛집</b>] 웨이팅 필수 HOT 한 신상 라멘 베스트 5'},
#  {'cnt': 23,
#   'description': '모루과자점, <b>부산 서면</b> 쇼쿠팡, <b>부산</b> 동래 밀한줌, 남천동 무슈뱅상, <b>서면</b> 아티성블렁제리빵빵빵, 태종대 하버커피, 동래 솦크렘샵, 대구 삼송빵집, 대구 대명동 프라리네, 대구 동성로 근대골목단팥빵, 대구 달서... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2170590',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2170590',
#   'pDate': '2024-08-31 00:05:00',
#   'title': "[안병익의 식신 <b>맛집</b>] 갓 구워내 구수한 '빵지순례' 필수코스! 베이커리..."},
#  {'cnt': 24,
#   'description': '미용봉사에 참여하는 미용사들은 <b>부산</b>진구 <b>서면</b>의 유명 미용실에서 현역으로 일하고 있는 베테랑들이다.... 평소 노을이 예쁘기로 입소문 나면서 환자나 간병 보호자들이 자주 찾아 ‘노을<b>맛집</b>’으로도 알려진 병원... ',
#   'link': 'https://ilyo.co.kr/?ac=article_view&entry_id=477786',
#   'org_link': 'https://ilyo.co.kr/?ac=article_view&entry_id=477786',
#   'pDate': '2024-08-24 00:02:00',
#   'title': '온종합병원, 미용·미술·음악·원예·요리·이벤트 등 봉사프로그램 운...'},
#  {'cnt': 25,
#   'description': '미용봉사에 참여하는 미용사들은 <b>부산</b>진구 <b>서면</b>의 유명 미용실에서 현역으로 일하고 있는 베테랑들이다.... 평소 노을이 예쁘기로 입소문 나면서 환자나 간병 보호자들이 자주 찾아 ‘노을<b>맛집</b>’으로도 알려진 병원... ',
#   'link': 'https://www.viva100.com/main/view.php?key=20240823010006253',
#   'org_link': 'https://www.viva100.com/main/view.php?key=20240823010006253',
#   'pDate': '2024-08-23 10:10:00',
#   'title': '온종합병원, 미용-미술-음악-원예-요리-이벤트 등 봉사프로그램 운영'},
#  {'cnt': 26,
#   'description': "미용봉사에 참여하는 미용사들은 <b>부산</b>진구 <b>서면</b>의 유명 미용실에서 현역으로 일하고 있는 베테랑들이다.... 평소 노을이 예쁘기로 입소문 나면서 환자나 간병 보호자들이 자주 찾아 '노을<b>맛집</b>'으로도 알려진 병원 옥상에서... ",
#   'link': 'https://n.news.naver.com/mnews/article/014/0005231500?sid=103',
#   'org_link': 'http://www.fnnews.com/news/202408230915423589',
#   'pDate': '2024-08-23 09:21:00',
#   'title': '&quot;의료진·봉사자 함께 환자사랑 실천하는 병원&quot;'},
#  {'cnt': 27,
#   'description': "타코 <b>맛집</b>'으로 큰 인기를 끌고 있다. 포테토칩 올디스타코맛은 포테토칩에 소고기와 치즈 풍미, 라임의... 서이브는 △홍대1호점 △<b>부산서면</b>태화점 △대구동성로점 총 3곳에서 팬미팅을 진행할 예정이다.",
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=651445',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=651445',
#   'pDate': '2024-08-20 11:36:00',
#   'title': '[오늘 뭐 먹지] 농심·오리온·롯데웰푸드 외'},
#  {'cnt': 28,
#   'description': "그는 전국 35개 체인점의 오너로 <b>부산 서면</b>에 위치한 '춘일' 오마카세 대표이기도 하다.대구에는 '귀신짬뽕... 지역 <b>맛집</b>으로 유명한 창업 동문들도 활발히 활동하고 있다. 현대그린푸드, 삼성웰스토리, 한화리조트 등... ",
#   'link': 'https://www.yeongnam.com/web/view.php?key=20240819010002277',
#   'org_link': 'https://www.yeongnam.com/web/view.php?key=20240819010002277',
#   'pDate': '2024-08-20 07:44:00',
#   'title': '[주목! 이 학과] 대구보건대 글로벌호텔조리학과'},
#  {'cnt': 29,
#   'description': '서울 물회 <b>맛집</b>으로는 노량진 형제상회, 강남구청 돌곰네, 청담 한미옥, 대치동 할매재첩국 대치점, 문래... 깃발집, <b>부산 서면</b> 포항물횟집, <b>부산</b> 송도 모아횟집, <b>부산</b> 광안리 할매재첩국 <b>부산</b>본점, <b>부산</b> 연산 녹산횟집... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2157236',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2157236',
#   'pDate': '2024-07-27 00:05:00',
#   'title': '[안병익의 식신 <b>맛집</b>] 매콤새콤 시원한 여름철 별미! 서울 물회 베스트...'},
#  {'cnt': 30,
#   'description': '18번 완당은 <b>서면</b>역에서 멀지 않은 곳에 위치해 접근성이 좋고, 가성비도 훌륭하다. 완당과 판모밀이 대표... 있는 테이블이 있긴 한데, 딱 하나라 사전 예약이 필요하다. 글·사진 이성균 기자 <b>부산</b><b>맛집</b>,<b>부산</b>먹거리,<b>부산</b>디저트',
#   'link': 'https://www.traveltimes.co.kr/news/articleView.html?idxno=408977',
#   'org_link': 'https://www.traveltimes.co.kr/news/articleView.html?idxno=408977',
#   'pDate': '2024-07-15 00:00:00',
#   'title': '에디터가 사랑하는 <b>부산</b>의 맛 총집합'},
#  {'cnt': 31,
#   'description': '- 방콕여행 등 경품 혜택도 푸짐 - 10층 놀이시설 등 재단장 진행 <b>부산</b> 대표 상권인 <b>부산</b>진구 <b>서면</b>에 위치한... 오후 4시부터 8층 ‘Q.라운지’에서는 DJ파티가 열리고, 스테이크 <b>맛집</b> ‘신도마켓’이 오는 14, 15일... ',
#   'link': 'https://n.news.naver.com/mnews/article/658/0000075938?sid=101',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0200&key=20240613.22010003498',
#   'pDate': '2024-06-13 03:05:00',
#   'title': '삼정타워서 쇼핑 축제 즐기세요'},
#  {'cnt': 32,
#   'description': '황인수가 <b>부산</b>광역시 <b>서면</b>에서 직접 운영하는 <b>맛집</b> ‘한대패’에서 촬영해 대답하기 곤란할 만한 질문들도 다수 포함됐다. 황인수는 2023년 2월 명현만과의 킥복싱 경기 이후 시합을 뛰고 있지 않다. MMA 경기는... ',
#   'link': 'https://m.sports.naver.com/general/article/144/0000965981',
#   'org_link': 'https://sports.khan.co.kr/news/sk_index.html?art_id=202406031834003&sec_id=530102&pt=nv',
#   'pDate': '2024-06-03 18:35:00',
#   'title': '황인수 “UFC가기 전에 김동현 꺾어보고 싶다”'},
#  {'cnt': 33,
#   'description': '생망고 <b>2</b>~3개가 온전히 들어간 일반적인 수제 홀케이크 사이즈 제품이다. 온라인에서는 “특급호텔 망고... 프랑제리는 망고 케이크 판매점을 경기 평촌과 야탑, <b>부산 서면</b> 등으로 확대할 계획이다. 싼데 품질은 더... ',
#   'link': 'https://n.news.naver.com/mnews/article/015/0004988728?sid=101',
#   'org_link': 'https://www.hankyung.com/article/202405241504i',
#   'pDate': '2024-05-24 16:17:00',
#   'title': "10만원짜리가 2만원…'초저가' 망고 케이크에 뒤집어졌다 [오형주의 산..."},
#  {'cnt': 34,
#   'description': "■ 우리나라 백화점 최초 ' 돼지국밥' 입점…단숨에 매출 1위 <b>부산 서면</b>의 한 백화점 9층 식당가에는 세계적인... 역시 <b>부산</b>에 본점을 둔 복국 <b>맛집</b>인데요. 복국이 남성들의 숙취 해소 메뉴라고 생각하면 오산. 요즘은 젊은... ",
#   'link': 'https://n.news.naver.com/mnews/article/056/0011726762?sid=102',
#   'org_link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=7970260&ref=A',
#   'pDate': '2024-05-23 10:59:00',
#   'title': '세계 유명 쉐프도 울리는 ‘<b>부산</b> <b>맛집</b>’…백화점 귀한 몸'},
#  {'cnt': 35,
#   'description': "인기 <b>맛집</b> 금액권도 한정 특가다. G마켓 '빅스마일데이'=G마켓과 옥션이 '빅스마일데이'를 통해 오는... <b>부산</b> '새로운 살구 정원'=롯데칠성음료(대표이사 박윤기)가 오는 17일부터 6월 9일까지 <b>부산 서면</b> 젊음의 거리에서... ",
#   'link': 'https://www.newsclaim.co.kr/news/articleView.html?idxno=3031070',
#   'org_link': 'https://www.newsclaim.co.kr/news/articleView.html?idxno=3031070',
#   'pDate': '2024-05-16 11:10:00',
#   'title': 'SPC 파리바게뜨 배달의민족 맥도날드 外(유통\ufeff家 이모저모)'},
#  {'cnt': 36,
#   'description': '중화요리집에 취직해 배달과 허드렛일을 하다가 <b>부산 서면</b>의 유명한 한식집인 한림정에서 일을 배울 기회가... 전국의 어떤 <b>맛집</b>보다 맛있다고 소문났습니다. 요리사에서 변신해 식품 가공을 하게 된 것은 제 인생의... ',
#   'link': 'https://www.joongdo.co.kr/web/view.php?key=20240512010001026',
#   'org_link': 'https://www.joongdo.co.kr/web/view.php?key=20240512010001026',
#   'pDate': '2024-05-12 19:00:00',
#   'title': '[한성일이 만난 사람]이재수 바른 한그릇 이가네식품 대표'},
#  {'cnt': 37,
#   'description': '음식은 <b>서면</b>점에서 취재했다. 사직거제점은 <b>부산</b> 거제역에서 가깝고, 주차장도 넉넉하게 마련되어 있다. 가게 앞에는 KNN명품<b>맛집</b>, 생방송투데이, 맛있는 녀석들에 나온 TV 방영 <b>맛집</b>이라고 쓰인 플래카드가 붙어있다.... ',
#   'link': 'http://www.foodnews.co.kr/news/articleView.html?idxno=107830',
#   'org_link': 'http://www.foodnews.co.kr/news/articleView.html?idxno=107830',
#   'pDate': '2024-04-30 10:38:00',
#   'title': "[<b>부산</b> 보양식 전문점 4선] 한약재 넣은 국내산 토종장어구이 '한방장어..."},
#  {'cnt': 38,
#   'description': '서울 성수점 5월 6일, <b>부산 서면</b>점 5월 12일까지 팝업스토어 운영 브랜드 컬러 로즈골드와 에메랄드 블루 적용... 근처 홍대를 찾았다가 친구들과 들렀다는 황 씨는 “근처 <b>맛집</b>에 왔다가 건물 외관을 보고 예뻐서 찾았다.... ',
#   'link': 'https://n.news.naver.com/mnews/article/022/0003927955?sid=101',
#   'org_link': 'http://www.segye.com/newsView/20240426513540?OutUrl=naver',
#   'pDate': '2024-04-27 04:37:00',
#   'title': '‘진로골드 판타지아’ 테마파크?…기자는 딱 한 잔만 ‘호록’ [밀착취...'},
#  {'cnt': 39,
#   'description': '해외 호텔 중 조식 <b>맛집</b> 1위는 일본 홋카이도에 있는 ‘센추리 로열 호텔’과 중국 산둥의 ‘포포인츠 바이... <b>부산</b> 비즈니스호텔은 <b>부산 서면</b> 중심부에 있는 4성급 호텔이다. 지하철역을 포함해 국제시장, 광안리 해변... ',
#   'link': 'https://n.news.naver.com/mnews/article/009/0005279491?sid=103',
#   'org_link': 'https://www.mk.co.kr/article/10976226',
#   'pDate': '2024-03-28 07:23:00',
#   'title': '여행자가 뽑은 국내외 ‘최고’ 숙박시설 어디 [여행가중계]'},
#  {'cnt': 40,
#   'description': "플래그십 스토어인 파르나스몰·SPC스퀘어·강남대로·<b>부산서면</b>중앙점에서는 100가지맛 아이스크림 메뉴를... 런던 베이글 뮤지엄은 젊은 소비자들 사이에서 '줄 서는 <b>맛집</b>'으로 통한다. 2021년 문을 연 1호 매장 안국점은... ",
#   'link': 'https://www.econovill.com/news/articleView.html?idxno=648285',
#   'org_link': 'https://www.econovill.com/news/articleView.html?idxno=648285',
#   'pDate': '2024-03-16 06:06:00',
#   'title': "요즘 대세는 '노티드·런베뮤'…원조 디저트 브랜드 생존전략은 [ER포커..."},
#  {'cnt': 41,
#   'description': '단박에 지역 <b>맛집</b>으로 명성을 얻었다. 아들이 합류하면서 식당 이름을 ‘봉식당’으로 바꿨다. 서양식으로... ‘카페 벽돌’(<b>부산</b>진구 <b>서면</b>로 46)도 지난해 여름 이 대열에 합류했다. 전리단길 다른 카페에 견줘 이 카페가... ',
#   'link': 'https://n.news.naver.com/mnews/article/028/0002677899?sid=103',
#   'org_link': 'https://www.hani.co.kr/arti/culture/culture_general/1129363.html',
#   'pDate': '2024-02-22 10:33:00',
#   'title': '<b>부산</b> 전포동이 ‘힙’포동 됐다…에스프레소 향 가득 ‘맛있는 <b>부산</b>’'},
#  {'cnt': 42,
#   'description': "■ KT&amp;G 상상마당 <b>부산</b>,'댄스 스튜디오' 개관 KT&amp;G(사장 백복인)가 <b>부산</b>광역시 <b>서면</b>에 위치한... 이번 신제품 역시 고기를 활용한 메뉴로, 남녀노소 누구나 좋아하는 떡갈비를 <b>맛집</b> 수준의 퀄리티로 간편하게 즐길 수 있는... ",
#   'link': 'http://www.biztribune.co.kr/news/articleView.html?idxno=302746',
#   'org_link': 'http://www.biztribune.co.kr/news/articleView.html?idxno=302746',
#   'pDate': '2024-01-24 16:52:00',
#   'title': '[브리프] SPC 풀무원 kt&amp;g 대상 정식품 해태제과 롯데칠성 유한킴벌리 外'},
#  {'cnt': 43,
#   'description': '관람객들은 루지, 바이애슬론 등 경기를 관람하고 시내 <b>맛집</b>에 들러 따뜻한 한 끼로 몸을 녹였다. 경기 북부... 이밖에 경기 수원 광교와 <b>부산 서면</b>·남포동·센텀시티, 인천 구월동 로데오거리 등 번화가의 대형마트와... ',
#   'link': 'https://www.goodnews1.com/news/articleView.html?idxno=430878',
#   'org_link': 'https://www.goodnews1.com/news/articleView.html?idxno=430878',
#   'pDate': '2024-01-21 23:18:00',
#   'title': "전국 겨울축제장 나들이 인파 '북적'"},
#  {'cnt': 44,
#   'description': '관람객들은 루지, 바이애슬론 등 경기를 관람하고 시내 <b>맛집</b>에 들러 따뜻한 한 끼로 몸을 녹였다. 경기 북부... 이밖에 경기 수원 광교와 <b>부산 서면</b>·남포동·센텀시티, 인천 구월동 로데오거리 등 번화가의 대형마트와... ',
#   'link': 'https://www.mstoday.co.kr/news/articleView.html?idxno=88095',
#   'org_link': 'https://www.mstoday.co.kr/news/articleView.html?idxno=88095',
#   'pDate': '2024-01-21 17:10:00',
#   'title': "전국 겨울축제장 뜨거운 열기⋯나들이 인파 '넘실'"},
#  {'cnt': 45,
#   'description': '관람객들은 루지, 바이애슬론 등 경기를 관람하고 시내 <b>맛집</b>에 들러 따뜻한 한 끼로 몸을 녹였다. 경기 북부... 이밖에 경기 수원 광교와 <b>부산 서면</b>·남포동·센텀시티, 인천 구월동 로데오거리 등 번화가의 대형마트와... ',
#   'link': 'https://n.news.naver.com/mnews/article/001/0014458076?sid=103',
#   'org_link': 'https://www.yna.co.kr/view/AKR20240121030700055?input=1195m',
#   'pDate': '2024-01-21 14:44:00',
#   'title': "전국 겨울축제장 뜨거운 열기…나들이 인파 '넘실'"},
#  {'cnt': 46,
#   'description': '전역의 <b>맛집</b>들을 한데 모아놨다. 아직 공사중이거나 입점 되지 않은 곳도 보였지만 명품 브랜드 10곳, 150개의... 우리나라에도 1990년대 서울 강남과 <b>부산 서면</b>에 각각 1, 2호점이 생겼다가 폐업한 바 있다. 일본에서는 별도... ',
#   'link': 'https://n.news.naver.com/mnews/article/088/0000857908?sid=103',
#   'org_link': 'https://www.imaeil.com/page/view/2024011711220077256',
#   'pDate': '2024-01-19 06:31:00',
#   'title': '[주말&amp;] 日 도쿄 최고층 전망대도, 90년 전통 맥줏집도 “줄 안서고 여유...'},
#  {'cnt': 47,
#   'description': '●아침을 깨우는 곳 큰손김밥 &amp; <b>서면</b>시장 아침 식사는 여행을 더 즐겁게 해줄 요소다. 선택지도 다양하다.... 풀카페는 호텔의 새로운 대표 공간으로 자리매김했다. 글·사진 이성균 기자 <b>부산</b>여행,<b>부산</b><b>맛집</b>,<b>부산</b>1호선',
#   'link': 'https://www.travie.com/news/articleView.html?idxno=51978',
#   'org_link': 'https://www.travie.com/news/articleView.html?idxno=51978',
#   'pDate': '2024-01-19 05:42:00',
#   'title': "'<b>부산</b> 1호선'으로 다녀온 <b>맛집</b> &amp; 여행지 7"},
#  {'cnt': 48,
#   'description': '서울 국밥 <b>맛집</b>으로는 명동 하동관, 인사동 이문설렁탕, 시청 무교동북어국집, 용두동 어머니대성집, 마포... 쌍둥이돼지국밥, <b>부산 서면</b> 송정3대국밥, 해운대 형제전통돼지국밥, <b>부산</b> 범일 60년전통할매국밥, 영도... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2073463',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=2073463',
#   'pDate': '2023-12-30 00:05:00',
#   'title': '[안병익의 식신 <b>맛집</b>] &quot;올해도 수고 많았어&quot; 마음을 위로 해주는 따뜻한...'},
#  {'cnt': 49,
#   'description': '또 <b>부산 서면</b>이랄지. 근데 요즘은 20대 초반 인구가 많이 줄고 있습니다. 이게 20년 전의 통계를 보면 지금... 그래서 예전에는 텔레비전 <b>맛집</b> 프로그램에 협찬을 해주고 나가는 그런 식당들이 많았고 또 거기 TV에 나왔다는... ',
#   'link': 'https://n.news.naver.com/mnews/article/056/0011625443?sid=101',
#   'org_link': 'https://news.kbs.co.kr/news/pc/view/view.do?ncd=7845628&ref=A',
#   'pDate': '2023-12-19 16:57:00',
#   'title': '[성공예감] 회식 때 2차 안 갑니다, ‘요리주점’이 뜨는 이유 – 노승욱...'},
#  {'cnt': 50,
#   'description': '◆무신사 스탠다드, 29일 <b>부산</b>에 <b>서면</b>점 공식 오픈 무신사 스탠다드가 이달 29일 <b>부산 서면</b>에 오프라인... 이와 함께 프리미엄 식재료를 비롯해 트렌디한 베이커리와 줄 서서 먹는 <b>맛집</b>까지 다양한 먹거리를 한자리에... ',
#   'link': 'https://dealsite.co.kr/articles/114727',
#   'org_link': 'https://dealsite.co.kr/articles/114727',
#   'pDate': '2023-12-14 10:44:00',
#   'title': '[오늘의 유통가] 이랜드리테일 통합멤버십 100만 회원 돌파 外'},
#  {'cnt': 51,
#   'description': '“대만에서 <b>부산</b> <b>맛집</b>으로 유명해 SNS를 보고 가족과 함께 왔습니다.” 지난 18일 오후 7시께 <b>부산 서면</b>... 센텀 스파랜드 관계자는 “외국인 <b>2</b>, 3명이 각자 다른 라면을 사는 사례가 많다”며 “라면 한 그릇이라도... ',
#   'link': 'https://n.news.naver.com/mnews/article/658/0000052946?sid=101',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0200&key=20230919.99002005834',
#   'pDate': '2023-09-19 17:09:00',
#   'title': "유명 관광지 찾아 '쫄쫄' 옛말…<b>부산</b> 온 외국인 “현지인처럼 즐긴다”"},
#  {'cnt': 52,
#   'description': "국제관광도시로 도약 다짐 [시장경제=강영범 기자] 11일 오후 <b>부산 서면</b> 롯데호텔에서 열린 '비짓<b>부산</b>패스... 가맹점은 <b>맛집</b>, 카페, 면세점, 박물관, 관광체험시설 등으로 구성된다. 한편 <b>부산</b>시와 <b>부산</b>관광공사는 올해... ",
#   'link': 'http://www.meconomynews.com/news/articleView.html?idxno=81625',
#   'org_link': 'http://www.meconomynews.com/news/articleView.html?idxno=81625',
#   'pDate': '2023-09-12 11:22:00',
#   'title': "<b>부산</b>시, 외국인 관광객 위한 '비짓<b>부산</b>패스 론칭쇼' 개최"},
#  {'cnt': 53,
#   'description': "11일 오후 <b>부산 서면</b> 롯데호텔에서 열린 '비짓<b>부산</b>패스 론칭쇼' 현장에서 발표에 나선 이정실... 사용가능한 가맹점은 <b>맛집</b>, 카페, 면세점, 박물관, 관광체험시설 등으로 구성된다. 이 사장은 &quot;이번 정식 출시에 맞춰... ",
#   'link': 'https://n.news.naver.com/mnews/article/003/0012082958?sid=102',
#   'org_link': 'http://www.newsis.com/view/?id=NISX20230911_0002446014&cID=10811&pID=10800',
#   'pDate': '2023-09-11 16:31:00',
#   'title': "'비짓<b>부산</b>패스' 12일 본격 운영…국제관광도시로 거듭난다"},
#  {'cnt': 54,
#   'description': '주변 직장인들은 물론 돈까스 <b>맛집</b>으로 유명해 항상 웨이팅이 길게 늘어선 곳이다. 심지어 오후 1시면 재료가... <b>부산 서면</b>에 위치한 티파니 돈까스에서는 오직 돈까스+오므라이스+떡만둣국 단일 메뉴만 판매한다. 심지어... ',
#   'link': 'http://www.esquirekorea.co.kr/article/80492',
#   'org_link': 'http://www.esquirekorea.co.kr/article/80492',
#   'pDate': '2023-09-08 20:56:00',
#   'title': '하루에 3시간만 운영하는 돈까스 <b>맛집</b> 4'},
#  {'cnt': 55,
#   'description': "선물세트 구성은 설향딸기 2팩(250g*<b>2</b>), 국내산 샤인머스켓 2송이, 브라질 애플망고 2개로 가격은 21만원이다.... 유명한 <b>부산 서면</b> 디저트 <b>맛집</b>인 '꼬숑드이지'의 팝업스토어를 오는 15일부터 내달 1일까지 더 센터 4층 '더... ",
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=612386',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=612386',
#   'pDate': '2023-09-07 14:54:00',
#   'title': '[오늘의 장바구니] 롯데백화점·애경산업·코웨이 외'},
#  {'cnt': 56,
#   'description': '31일 <b>부산</b>진구 등에 따르면 사건은 지난 6월 발생했다. <b>서면</b>에서 50년 넘게 ‘양곱창 <b>맛집</b>’으로 이름을 날린 A 가게는 13개의 양곱창집이 한 곳에 모여있는 이른바 ‘코너식’ 가게다. 공간은 같이 쓰지만 각자 다른 주인이... ',
#   'link': 'https://n.news.naver.com/mnews/article/658/0000051195?sid=102',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0300&key=20230901.22014010110',
#   'pDate': '2023-08-31 19:40:00',
#   'title': '‘한지붕 13명 사장님’ 양곱창집, 일괄 행정처분 논란'},
#  {'cnt': 57,
#   'description': "- 푸짐한 (?)원 대구뽈탕백반 ◈ 부전시장왕뽈떼기 본점 : <b>부산 서면 맛집</b> '부전시장왕뽈떼기 본점'을 찾아 단돈 5천원의 대구뽈탕 백반 맛을 소개한다. 대표 메뉴 : 대구뽈탕 백반 (?)원 (라스트오더 오후 2시 30분)... ",
#   'link': 'https://www.foodneconomy.com/news/articleView.html?idxno=349216',
#   'org_link': 'https://www.foodneconomy.com/news/articleView.html?idxno=349216',
#   'pDate': '2023-08-11 18:06:00',
#   'title': "[2TV 생생정보 <b>맛집</b>] '대구뽈탕' '무안 낙지' <b>맛집</b>"},
#  {'cnt': 58,
#   'description': "- 푸짐한 (?)원 대구뽈탕백반 ◈ 부전시장왕뽈떼기 본점 : <b>부산 서면 맛집</b> '부전시장왕뽈떼기 본점'을 찾아 단돈 5천원의 대구뽈탕 백반 맛을 소개한다. 대표 메뉴 : 대구뽈탕 백반 (?)원 (라스트오더 오후 2시 30분)... ",
#   'link': 'http://www.queen.co.kr/news/articleView.html?idxno=392205',
#   'org_link': 'http://www.queen.co.kr/news/articleView.html?idxno=392205',
#   'pDate': '2023-08-11 17:02:00',
#   'title': "[2TV 생생정보 <b>맛집</b>] '대구뽈탕' 가격파괴 <b>맛집</b>"},
#  {'cnt': 59,
#   'description': "'강석우의 종점여행 시즌2'에서 찾은 <b>부산</b> <b>부산</b>진구 <b>서면</b> 소재 밀면·비빔밀면 <b>맛집</b>이 뜨거운 화제다. 22일 MBN '강석우의 종점여행 시즌2'에서는 <b>부산</b>광역시 <b>부산</b>진구을 방문, 다양한 장소를 찾아 눈길을 끌었다. 강석우가... ",
#   'link': 'http://www.topstarnews.net/news/articleView.html?idxno=15370745',
#   'org_link': 'http://www.topstarnews.net/news/articleView.html?idxno=15370745',
#   'pDate': '2023-07-22 17:06:00',
#   'title': "'강석우의 종점여행 시즌2' <b>부산 서면</b> 밀면 <b>맛집</b> 위치는? 수많은 연예인..."},
#  {'cnt': 60,
#   'description': '콜라보 카페는 6월 29일을 시작으로 8월 6일까지 운영되며, 애니플러스 서울 합정점과 <b>부산 서면</b>점에서... <b>맛집</b>이라고 소문날 정도의 맛은 아니지만 괜찮은 맛이다. 무엇보다 각 메뉴에 들어간 니케의 색감이나 특징이 해당... ',
#   'link': 'http://www.gameshot.net/common/con_view.php?code=GA649e286255165',
#   'org_link': 'http://www.gameshot.net/common/con_view.php?code=GA649e286255165',
#   'pDate': '2023-06-30 10:06:00',
#   'title': '‘승리의 여신 니케’ 애니플러스 콜라보 카페에 가 본 썰'},
#  {'cnt': 61,
#   'description': "블루 아카이브 한국 출시 1주년을 기념해 열린 콜라보 카페는 애니플러스 서울 합정점과 <b>부산 서면</b>점... 아메리카노'나 '<b>맛집</b>순회 이후 입가심으로 마시는 자몽에이드' 등 유저라면 누구나 떠올릴 수 있는 메뉴가... ",
#   'link': 'http://www.gamechosun.co.kr/webzine/article/view.php?no=195167',
#   'org_link': 'http://www.gamechosun.co.kr/webzine/article/view.php?no=195167',
#   'pDate': '2023-06-24 12:02:00',
#   'title': "[조선통신사] 액정 뚫고 나온 미소녀 '캐릭터 게임 콜라보 카페', 팬심과..."},
#  {'cnt': 62,
#   'description': "동성로, <b>부산 서면</b> 등 젊은 층이 모이는 번화가에 팝업 스토어 '켈리 라운지'도 열었다. 오비멕주 역시 1위 수성에 나선다. 카스는 온라인 마케팅을 벌이고 있다. 소비자가 <b>맛집</b>을 추천하는 '카스 어디집', 지인에게... ",
#   'link': 'http://www.dailyimpact.co.kr/news/articleView.html?idxno=97087',
#   'org_link': 'http://www.dailyimpact.co.kr/news/articleView.html?idxno=97087',
#   'pDate': '2023-05-03 15:10:00',
#   'title': "'존재감' 사라진 클라우드…재기 가능할까"},
#  {'cnt': 63,
#   'description': '<b>맛집</b>을 탐방하듯 각 베이커리의 시그니처를 도장깨기하고 있는 빵덕후들을 위한 핫한 베이커리 카페를... 모루과자점,<b>부산 서면</b> 쇼쿠팡,<b>부산</b> 동래 밀한줌,남천동 무슈뱅상,<b>서면</b> 아티성블렁제리빵빵빵,태종대 에쎄떼... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1657767',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1657767',
#   'pDate': '2023-04-29 00:05:00',
#   'title': "[안병익의 식신 <b>맛집</b>] '빵지순례' 필수코스···서울 핫한 베이커리 카..."},
#  {'cnt': 64,
#   'description': "관계자는 &quot;곳곳에 포토존을 설치해 '포토<b>맛집</b>'을 선보였다&quot;며 &quot;특히 SNS에 릴스, 쇼츠 같은 숏폼 영상이... 한편, 이번 팝업스토어는 서울(강남)과 대구(동성로), <b>부산</b>(<b>서면</b>)에서 진행된다. 미성년자 출입은 제한되며, 5월... ",
#   'link': 'http://www.todaykorea.co.kr/news/articleView.html?idxno=307241',
#   'org_link': 'http://www.todaykorea.co.kr/news/articleView.html?idxno=307241',
#   'pDate': '2023-04-21 10:30:00',
#   'title': "[발자국] &quot;퇴근하고 여기서 맥주에 게임 한판?&quot;···하이트진로, '켈리..."},
#  {'cnt': 65,
#   'description': '이번 팝업 스토어는서울(강남)과 대구(동성로), <b>부산</b>(<b>서면</b>)에서 진행되며미성년자 출입은 제한된다. 켈리... 돈까스안주 <b>맛집</b> 등 레트로한 감성을 부각할 수 있어 SNS 마케팅에도 유리하다. 특히 대왕돈까스와 함께... ',
#   'link': 'http://www.newsprime.co.kr/news/article.html?no=599052',
#   'org_link': 'http://www.newsprime.co.kr/news/article.html?no=599052',
#   'pDate': '2023-04-18 17:10:00',
#   'title': '[오늘 뭐 먹지] KFC·하이트진로·LF푸드 외'},
#  {'cnt': 66,
#   'description': '비주얼적으로 돋보여 돈까스안주 <b>맛집</b> 등 레트로한 감성을 부각할 수 있어 SNS 마케팅에도 유리하다.... 이번 팝업 스토어는서울(강남)과 대구(동성로), <b>부산</b>(<b>서면</b>)에서 진행되며미성년자 출입은 제한된다. 켈리... ',
#   'link': 'http://www.g-enews.com/ko-kr/news/article/news_all/20230418104409225941b72ae004_1/article.html',
#   'org_link': 'http://www.g-enews.com/ko-kr/news/article/news_all/20230418104409225941b72ae004_1/article.html',
#   'pDate': '2023-04-18 11:10:00',
#   'title': '[유통산책] 신세계푸드, ‘제이릴라’ 2차 NFT 발행 外'},
#  {'cnt': 67,
#   'description': "이번 팝업 스토어는서울(강남)과 대구(동성로), <b>부산</b>(<b>서면</b>)에서 진행되며 미성년자 출입은 제한된다. 켈리... 석촌호수 인근 카페∙<b>맛집</b> 성지 '송리단길'에 새로운 '핫 플레이스'가 탄생했다. 치킨과 브런치를 함께 즐길... ",
#   'link': 'http://www.greened.kr/news/articleView.html?idxno=302632',
#   'org_link': 'http://www.greened.kr/news/articleView.html?idxno=302632',
#   'pDate': '2023-04-18 10:28:00',
#   'title': "[유통가 레이더] CJ제일제당, '엑티브엔리치' 론칭... 글로벌 뉴트리션..."},
#  {'cnt': 68,
#   'description': '비즈엔터 홍선화 기자 | ‘어서와 한국은 처음이지’ 영국 신사 4인방이 해운대에서 복국 한 상, <b>서면</b> 매생이... 23일 방송되는 MBC에브리원 ‘어서와 한국은 처음이지’에서는 영국 친구들의 <b>부산</b> <b>맛집</b> 기행이 펼쳐진다.... ',
#   'link': 'http://enter.etoday.co.kr/news/view/238999',
#   'org_link': 'http://enter.etoday.co.kr/news/view/238999',
#   'pDate': '2023-03-23 20:28:00',
#   'title': '영국 친구들, <b>부산</b> 해운대 복국 <b>맛집</b>ㆍ<b>서면</b> 매생이 연포탕&amp;보쌈ㆍ요트투...'},
#  {'cnt': 69,
#   'description': '복요리를 시작으로 영국 친구들의 <b>부산</b> <b>맛집</b> 기행은 계속된다. <b>부산 서면</b>으로 향한 친구들은 팀이 평소 즐겨 먹는다는 매생이 연포탕과 보쌈에 도전한다. 팀은 친구들에게 돼지고기에 보쌈김치를 한입에 먹는 팁을... ',
#   'link': 'https://m.entertain.naver.com/article/003/0011754279',
#   'org_link': 'http://www.newsis.com/view/?id=NISX20230321_0002234681&cID=10601&pID=10600',
#   'pDate': '2023-03-21 13:06:00',
#   'title': "'복국부터 연포탕까지'…영국 친구들의 <b>부산</b> <b>맛집</b> 기행"},
#  {'cnt': 70,
#   'description': '복요리를 시작으로 영국 친구들의 <b>부산</b> <b>맛집</b> 기행은 계속된다. 먹거리 가득한 <b>부산 서면</b>으로 향한 친구들은 팀이 평소 즐겨 먹는다는 매생이 연포탕과 보쌈에 도전한다. 팀은 친구들에게 돼지고기에 새콤한 보쌈김치를... ',
#   'link': 'https://www.bntnews.co.kr/article/view/bnt202303210041',
#   'org_link': 'https://www.bntnews.co.kr/article/view/bnt202303210041',
#   'pDate': '2023-03-21 11:00:00',
#   'title': '‘어서와’ 英 친구들, 복국 한 술 뜨고 “캬아”... 아재 입맛 저격할...'},
#  {'cnt': 71,
#   'description': '복요리를 시작으로 영국 친구들의 <b>부산</b> <b>맛집</b> 기행은 계속된다. 먹거리 가득한 <b>부산 서면</b>으로 향한 친구들은 팀이 평소 즐겨 먹는다는 매생이 연포탕과 보쌈에 도전한다. 팀은 친구들에게 돼지고기에 새콤한 보쌈김치를... ',
#   'link': 'https://m.entertain.naver.com/article/312/0000602172',
#   'org_link': 'https://tenasia.hankyung.com/tv/article/2023032128154',
#   'pDate': '2023-03-21 10:57:00',
#   'title': "영국 친구들, 연포탕 먹을 줄 아네..K-아재 다 됐다 ('어서와')"},
#  {'cnt': 72,
#   'description': '복요리를 시작으로 영국 친구들의 <b>부산</b> <b>맛집</b> 기행은 계속된다. 먹거리 가득한 <b>부산 서면</b>으로 향한 친구들은 팀이 평소 즐겨 먹는다는 매생이 연포탕과 보쌈에 도전한다. 팀은 친구들에게 돼지고기에 새콤한 보쌈김치를... ',
#   'link': 'https://m.entertain.naver.com/article/408/0000183562',
#   'org_link': 'http://enews.imbc.com/News/RetrieveNewsInfo/376785',
#   'pDate': '2023-03-21 10:42:00',
#   'title': "'어서와' 영국 친구들, 복국→연포탕까지…K-국물 맛에 리액션 폭발"},
#  {'cnt': 73,
#   'description': '복요리를 시작으로 영국 친구들의 <b>부산</b> <b>맛집</b> 기행은 계속된다. 먹거리 가득한 <b>부산 서면</b>으로 향한 친구들은 팀이 평소 즐겨 먹는다는 매생이 연포탕과 보쌈에 도전한다. 팀은 친구들에게 돼지고기에 새콤한 보쌈김치를... ',
#   'link': 'https://m.entertain.naver.com/article/609/0000703211',
#   'org_link': 'https://www.newsen.com/news_view.php?uid=202303211001480410',
#   'pDate': '2023-03-21 10:04:00',
#   'title': '영국 친구들, 복국→연포탕까지…K-국물맛에 아재 리액션 폭발(어서와한...'},
#  {'cnt': 74,
#   'description': '다만 전성기에는 매장 수가 44개에 달했으나 현재는 ▲서울 송파점 ▲<b>부산 서면</b>점 ▲인천 논현점 3개점으로... 숨은 <b>맛집</b>을 찾아다니는 게 유행을 하면서 산업 자체가 정체된 배경이됐다”고 설명했다. ◇ 어려움 속에서도... ',
#   'link': 'https://n.news.naver.com/mnews/article/119/0002691987?sid=101',
#   'org_link': 'https://www.dailian.co.kr/news/view/1211089/?sc=Naver',
#   'pDate': '2023-03-14 07:22:00',
#   'title': '“물가상승·인건비 폭탄”…‘자연별곡’, 화려한 부활할까'},
#  {'cnt': 75,
#   'description': '“한 시간 이상 줄 서야 한다고요?” <b>맛집</b>으로 떠오른 한 고깃집 얘기다. 동그란 테이블에 앉아 직원이... <b>부산 서면</b> 일대 다양한 한식 버전으로 약 10여개 직영점, 전포동 카페거리에 대형 베이커리, 카페 등을 계속... ',
#   'link': 'https://n.news.naver.com/mnews/article/024/0000080593?sid=101',
#   'org_link': 'https://www.mk.co.kr/article/10677157',
#   'pDate': '2023-03-11 10:15:00',
#   'title': '홍콩서 日매출 2000만원 ‘전포식육’...K푸드 해외 진출 공식 바꿨다 [...'},
#  {'cnt': 76,
#   'description': "전국 하이볼 <b>맛집</b>으로는 <b>부산</b> 미드나잇하이볼클럽, <b>부산 서면</b> 올굿, 수원 우주 하이볼바, 광명 광명하이볼, 천안 덕희하이볼클럽 등이 있다. ◇눈길 끄는 비주얼의 파스타 케이크와 시원한 하이볼, 서울대 '정전기... ",
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1638807',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1638807',
#   'pDate': '2023-02-18 00:05:00',
#   'title': '[안병익의 식신 <b>맛집</b>] 청량한 탄산 바다에 빠져든다~ 상큼 터지는 하이...'},
#  {'cnt': 77,
#   'description': '“이름만 듣고 연남장이 중국집인 줄 알았다”고 말한 윤 전 총장은, 단순히 <b>맛집</b>이나 핫플레이스가 아닌... “2000년대 초 오프라인 상권은 도심(명동, 강남역, <b>부산 서면</b>, 대구 동성로 등 도심 중심지), 전통시장, 근린상권... ',
#   'link': 'https://n.news.naver.com/mnews/article/262/0000016207?sid=102',
#   'org_link': 'https://shindonga.donga.com/3/all/13/3901123/1',
#   'pDate': '2023-01-21 10:02:00',
#   'title': '“서울이 글로벌 시티가 된 이유요? 동네가 강한 도시여서예요”'},
#  {'cnt': 78,
#   'description': '서울 국밥 <b>맛집</b>으로는 명동 하동관, 인사동 이문설렁탕, 시청 무교동북어국집, 용두동 어머니대성집, 마포... 쌍둥이돼지국밥, <b>부산 서면</b> 송정3대국밥, 해운대 형제전통돼지국밥, <b>부산</b> 범일 60년전통할매국밥, 영도... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1627790',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1627790',
#   'pDate': '2023-01-02 16:36:00',
#   'title': '[안병익의 식신 <b>맛집</b>] &quot;올해도 정말 고생 많았어&quot; 우리 모두를 위로해주...'},
#  {'cnt': 79,
#   'description': '인터넷 검색을 통해서 <b>맛집</b>을 찾아간다. 하지만 이런 현상은 입지의 중요성이 덜해졌다는 의미이지 상권이... 서울 성수동이나 홍대 강남, <b>부산</b>의 <b>서면</b>이나 남포동처럼 거리가 먼 지역에서도 고객을 끌어들이는 흡입력이... ',
#   'link': 'http://www.ilyoseoul.co.kr/news/articleView.html?idxno=470005',
#   'org_link': 'http://www.ilyoseoul.co.kr/news/articleView.html?idxno=470005',
#   'pDate': '2022-12-23 18:46:00',
#   'title': '텅빈 상가에서 창업해 대박난 식당의 비결은'},
#  {'cnt': 80,
#   'description': '한편, 프랑제리의 사과빵은 전국 프랑제리 매장(신촌, 한강공원, 평촌, 야탑, 분당, <b>부산서면</b>, 대전유성... 이번에 선보인 밀키트는 <b>부산</b>에서 맛과 청결, 수준 높은 서비스로 유명한 <b>부산</b>지역 <b>맛집</b>의 대표메뉴로 구성됐다.... ',
#   'link': 'http://www.greened.kr/news/articleView.html?idxno=299629',
#   'org_link': 'http://www.greened.kr/news/articleView.html?idxno=299629',
#   'pDate': '2022-12-20 09:58:00',
#   'title': "[유통가 레이더] &quot;정통 이탈리아 파스타를 집에서&quot;... 오뚜기, '파스타 ..."},
#  {'cnt': 81,
#   'description': '해운대와 광안대교, <b>부산</b>항과 <b>서면</b>, <b>부산</b>진구 일대까지 <b>부산</b>을 한눈에 조망할 수 있는 황령산 봉수대에... ▶ <b>서면</b>의 인생<b>맛집</b>, 양곱창 골목 해가 지고 저녁이 되면 진가를 찾는 <b>서면</b>의 번화가. 퇴근한 직장인들이... ',
#   'link': 'http://www.cbci.co.kr/news/articleView.html?idxno=436208',
#   'org_link': 'http://www.cbci.co.kr/news/articleView.html?idxno=436208',
#   'pDate': '2022-12-17 17:38:00',
#   'title': "이만기 '동네 한 바퀴' <b>부산</b>진구 이웃들 이야기"},
#  {'cnt': 82,
#   'description': '해운대와 광안대교, <b>부산</b>항과 <b>서면</b>, <b>부산</b>진구 일대까지 <b>부산</b>을 한눈에 조망할 수 있는 황령산 봉수대에 올라... ▶ <b>서면</b>의 인생<b>맛집</b>, 양곱창 골목 해가 지고 저녁이 되면 진가를 찾는 <b>서면</b>의 번화가. 퇴근한 직장인들이... ',
#   'link': 'https://www.gukjenews.com/news/articleView.html?idxno=2616688',
#   'org_link': 'https://www.gukjenews.com/news/articleView.html?idxno=2616688',
#   'pDate': '2022-12-17 17:18:00',
#   'title': "'동네 한 바퀴' 이만기, <b>부산 서면</b>시장 돼지국밥·양곱창 탐방"},
#  {'cnt': 83,
#   'description': '해운대와 광안대교, <b>부산</b>항과 <b>서면</b>, <b>부산</b>진구 일대까지 <b>부산</b>을 한눈에 조망할 수 있는 황령산 봉수대에 올라... <b>서면</b>의 인생<b>맛집</b>, 양곱창 골목 사진 = KBS 제공\u200b 해가 지고 저녁이 되면 진가를 찾는 <b>서면</b>의 번화가. 퇴근한... ',
#   'link': 'https://www.mhns.co.kr/news/articleView.html?idxno=543495',
#   'org_link': 'https://www.mhns.co.kr/news/articleView.html?idxno=543495',
#   'pDate': '2022-12-17 17:12:00',
#   'title': "이만기가 안내하는 '동네 한 바퀴' 나란히 걷는다, 그 마음 - <b>부산</b> <b>부산</b>..."},
#  {'cnt': 84,
#   'description': '해운대와 광안대교, <b>부산</b>항과 <b>서면</b>, <b>부산</b>진구 일대까지 <b>부산</b>을 한눈에 조망할 수 있는 황령산 봉수대에 올라... ▶ <b>서면</b>의 인생<b>맛집</b>, 양곱창 골목 해가 지고 저녁이 되면 진가를 찾는 <b>서면</b>의 번화가. 퇴근한 직장인들이... ',
#   'link': 'http://www.joygm.com/news/articleView.html?idxno=200820',
#   'org_link': 'http://www.joygm.com/news/articleView.html?idxno=200820',
#   'pDate': '2022-12-17 12:22:00',
#   'title': "'동네한바퀴' <b>부산</b>진구 황령산 봉수대· 돼지국밥· 호천마을· 전포동 ..."},
#  {'cnt': 85,
#   'description': "마음 – <b>부산</b> <b>부산</b>진구' 편에서는 <b>부산</b>진구 전포동에서 가볼만한 곳과 먹거리 <b>맛집</b>을 소개한다. 대한민국... 해운대와 광안대교, <b>부산</b>항과 <b>서면</b>, <b>부산</b>진구 일대까지 <b>부산</b>을 한눈에 조망할 수 있는 황령산 봉수대에 올라... ",
#   'link': 'https://www.lecturernews.com/news/articleView.html?idxno=114446',
#   'org_link': 'https://www.lecturernews.com/news/articleView.html?idxno=114446',
#   'pDate': '2022-12-17 06:06:00',
#   'title': "'동네 한 바퀴'이만기…황령산 봉수대 <b>서면</b> 돼지국밥 양곱창 골목 전포..."},
#  {'cnt': 86,
#   'description': '전국의 갓포요리 및 가이세키 <b>맛집</b>으로는 분당 아오이, 송도 텐메이, 송도 갓포서진, <b>부산 서면</b> 모모야마, 해운대 사까에, 해운대 큐노, 울산 달동 갓포이찌, 제주 애월 제주이와이, 제주시 갓포아키 등이 유명하다.... ',
#   'link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1622084',
#   'org_link': 'http://www.enewstoday.co.kr/news/articleView.html?idxno=1622084',
#   'pDate': '2022-12-11 01:31:00',
#   'title': '[안병익의 식신 <b>맛집</b>] 정갈하고 세련된 요리와 술의 페어링, 갓포요리 ...'},
#  {'cnt': 87,
#   'description': '패션 브랜드 아더에러가 지난 11월에 <b>부산 서면</b>에 ‘아더 <b>서면</b> 스페이스’를 오픈했습니다. 기존의 홍대... 해운대 웨이팅 <b>맛집</b>으로 소문난 곳으로 오픈런을 도전해보세요. 준비된 수량이 모두 소진 시 마감되니 참고할... ',
#   'link': 'https://www.allurekorea.com/2022/12/02/%ec%9d%b4%eb%b2%88-%ec%a3%bc%eb%a7%90-%ec%96%b4%eb%94%94%ea%b0%80%ec%a7%80-%eb%94%b0%eb%9c%bb%ed%95%9c-%eb%b6%80%ec%82%b0-%eb%8b%b9%ec%9d%bc%ec%b9%98%ea%b8%b0-%ec%97%ac%ed%96%89-%ec%bd%94%ec%8a%a4-5/?utm_source=naver&utm_medium=partnership',
#   'org_link': 'https://www.allurekorea.com/2022/12/02/%ec%9d%b4%eb%b2%88-%ec%a3%bc%eb%a7%90-%ec%96%b4%eb%94%94%ea%b0%80%ec%a7%80-%eb%94%b0%eb%9c%bb%ed%95%9c-%eb%b6%80%ec%82%b0-%eb%8b%b9%ec%9d%bc%ec%b9%98%ea%b8%b0-%ec%97%ac%ed%96%89-%ec%bd%94%ec%8a%a4-5/?utm_source=naver&utm_medium=partnership',
#   'pDate': '2022-12-02 15:46:00',
#   'title': '<b>부산</b> 당일치기 겨울 바다 여행 <b>맛집</b> 핫플레이스 코스 가볼만한 곳 추천...'},
#  {'cnt': 88,
#   'description': '다짜고짜 딴지 인증, 대통령 <b>맛집</b>(일 수도 있는) 식당으로 확정. 붓싼 풀코스 4 : <b>서면</b>, 촛불 든 사람들 2019년, 검찰과 언론이 조국 일가를 탈탈 털고 있을 때. <b>부산 서면</b>과 <b>부산</b> 지방 검찰청 앞에서 집회가 열렸더랬다. 3차... ',
#   'link': 'http://www.ddanzi.com/757536077',
#   'org_link': 'http://www.ddanzi.com/757536077',
#   'pDate': '2022-11-29 18:12:00',
#   'title': '[촛불로드]우리가 남이가 : <b>부산</b> 촛불 집회 현장을 가다'},
#  {'cnt': 89,
#   'description': '그 뿐만 아니라 아로나 딸기 라떼, 백야당의 기운충전 녹차&amp;모나카 세트, <b>맛집</b>순회 자몽에이드, 선도부장님... 컬래버 카페는 애니플러스 서울 합정점과 애니플러스 <b>부산 서면</b>점에서 11월 10일~ 12월 25일 총 6주간 개최된다.',
#   'link': 'https://n.news.naver.com/mnews/article/356/0000056891?sid=004',
#   'org_link': 'https://www.gamemeca.com/mv.php?inflow=naver_s&gid=1687998',
#   'pDate': '2022-11-07 17:33:00',
#   'title': '몰?루콘 쿠키 먹을 수 있는 블루 아카이브 카페, 10일 오픈'},
#  {'cnt': 90,
#   'description': '<b>맛집</b> 검색 플랫폼 식신을 통해 지역 곳곳의 ‘빵지순례’ 명소를 알아봤다. 꼼다비뛰드 : 평점 4.6 ‘comme d... 베이커스 : 평점 4.1 <b>부산 서면</b>의 카페거리에 있는 빵집이다. 단출하면서도 따뜻한 느낌의 소품들과 인테리어가... ',
#   'link': 'https://www.etoday.co.kr/news/view/2185887',
#   'org_link': 'https://www.etoday.co.kr/news/view/2185887',
#   'pDate': '2022-10-26 14:12:00',
#   'title': '[이슈크래커] SPC 불매운동에 동네 빵집이 뜬다'},
#  {'cnt': 91,
#   'description': '#<b>부산</b><b>맛집</b>. <b>서면</b> 포항돼지국밥 <b>서면</b> 돼지국밥 골목의 1티어 국밥집. 로컬의 주문 팁 고기와 순대가 모두 들어가 있는 순대국밥을 추천한다. 순대는 ‘막장’이 아닌 간장에 찍어 먹는 것이 이 집만의 묘미와 재미. 주소... ',
#   'link': 'https://www.gqkorea.co.kr/2022/10/10/bts-%eb%b6%80%ec%82%b0-%ec%bd%98%ec%84%9c%ed%8a%b8-%eb%b6%80%ec%82%b0-%ea%b5%ad%ec%a0%9c-%ec%98%81%ed%99%94%ec%a0%9c-%eb%b6%80%ec%82%b0-%eb%a7%9b%ec%a7%91/?utm_source=naver&utm_medium=partnership',
#   'org_link': 'https://www.gqkorea.co.kr/2022/10/10/bts-%eb%b6%80%ec%82%b0-%ec%bd%98%ec%84%9c%ed%8a%b8-%eb%b6%80%ec%82%b0-%ea%b5%ad%ec%a0%9c-%ec%98%81%ed%99%94%ec%a0%9c-%eb%b6%80%ec%82%b0-%eb%a7%9b%ec%a7%91/?utm_source=naver&utm_medium=partnership',
#   'pDate': '2022-10-10 16:32:00',
#   'title': '<b>부산</b> 출신 에디터가 추천하는 <b>부산</b> <b>맛집</b>'},
#  {'cnt': 92,
#   'description': '쿠팡이츠, 돼지국밥 <b>맛집</b>의 비결 공개…<b>부산 서면</b>에서 광고 없이 성장 풍성돼지국밥 한진영 사장.(사진=쿠팡) 쿠팡이츠로 <b>부산 서면</b>에서 <b>맛집</b>으로 거듭난 풍성돼지국밥의 비법이 주목받고 있다. 풍성돼지국밥 한진영... ',
#   'link': 'https://www.asiatime.co.kr/article/20220916500080',
#   'org_link': 'https://www.asiatime.co.kr/article/20220916500080',
#   'pDate': '2022-09-16 11:02:00',
#   'title': '[AT 유통 소식] 교촌치킨·우아한청년들·GS25·쿠팡이츠'},
#  {'cnt': 93,
#   'description': '쿠팡이츠로 <b>부산 서면</b>에서 <b>맛집</b>으로 거듭난 풍성돼지국밥의 비법이 주목받고 있다. 풍성돼지국밥 한진영... 4.<b>2</b>%에 달한다. 이 중 50명의 파트너는 동등한 승진 기회를 얻어 관리자 이상 직급으로 근무 중이다. 이번에... ',
#   'link': 'http://www.greened.kr/news/articleView.html?idxno=297732',
#   'org_link': 'http://www.greened.kr/news/articleView.html?idxno=297732',
#   'pDate': '2022-09-16 10:22:00',
#   'title': "[유통가 레이더] 버려진 자전거의 부활... 롯데마트, '재생자전거 팝업..."},
#  {'cnt': 94,
#   'description': '경남, 울산으로 확대 대선주조는 <b>부산</b>‧경남‧울산 주요 상권에서 지난 5월 23일부터 <b>서면</b>, 연산동, 해운대... 게시물에는 가게 이름과 메뉴 이름, 지역을 필수로 ‘맛스타그램’, ‘<b>부산</b><b>맛집</b>’ 등 여러 사람들의... ',
#   'link': 'https://www.ajunews.com/view/20220725140147956',
#   'org_link': 'https://www.ajunews.com/view/20220725140147956',
#   'pDate': '2022-07-25 15:56:00',
#   'title': "대선주조‧한화리조트 '협업' MZ 세대 관광객 타켓 外"},
#  {'cnt': 95,
#   'description': '숨은 <b>맛집</b>을 찾아다니는 게 유행을 하면서 산업 자체가 정체되기 시작했다”고 말했다. 이어 “코로나... 자연별곡은 현재 3곳(서울 송파점, 인천 논현점, <b>부산 서면</b>점)을 운영하고 있다. 송파점의 경우 프리미엄 모델... ',
#   'link': 'https://n.news.naver.com/mnews/article/119/0002623301?sid=101',
#   'org_link': 'https://www.dailian.co.kr/news/view/1134858/?sc=Naver',
#   'pDate': '2022-07-22 07:02:00',
#   'title': '고물가에 한식뷔페 인기?…관건은 인건비·식자재비 뺀 ‘수익성’'},
#  {'cnt': 96,
#   'description': '주변 음식점들이 ‘더현대 서울 <b>맛집</b>’이라는 식으로 공격적인 마케팅을 이어가면서 주말 매출도 상당... <b>부산 서면</b>과 대구 동성로를 제외하고는 순위권에 든 지역이 없었다. 광주 상무지구, 대전 둔산동·은행동, 인천... ',
#   'link': 'https://n.news.naver.com/mnews/article/024/0000076029?sid=101',
#   'org_link': 'https://www.mk.co.kr/economy/view/2022/578764',
#   'pDate': '2022-07-08 15:43:00',
#   'title': "가로수길은 '의료', 홍대입구는 '외식'... 상권별 매출 효자는?"},
#  {'cnt': 97,
#   'description': '<b>부산</b> <b>부산</b>진구 <b>서면</b>문화로(부전동)에 위치한 갈비탕집 ‘사미헌’이 휴가철 <b>맛집</b>으로 추천됐다. 마켓컬리 운영사 컬리는 올해 1월부터 지난 15일까지 판매된 레스토랑 간편식을 분석했더니 사미헌의 갈비탕이 전국 1위를... ',
#   'link': 'https://n.news.naver.com/mnews/article/658/0000013059?sid=101',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0200&key=20220625.99099006939',
#   'pDate': '2022-06-25 14:41:00',
#   'title': '<b>부산</b> 사미헌 갈비탕 휴가철 <b>맛집</b> 급부상…전국 2위는 전주 베테랑 칼국...'},
#  {'cnt': 98,
#   'description': '춘하추동 밀면 물밀면, 비빔밀면, 만두 주소 <b>부산</b>시 <b>부산</b>진구 <b>서면</b>문화로 48-1 문의 051-809-8659 45. 충렬통닭 버거앤치킨 수제버거, 후라이드치킨 주소 <b>부산</b>시 동래구 사직북로47번길 20-<b>2</b> 문의 0507-1387... ',
#   'link': 'https://www.gqkorea.co.kr/2022/06/08/%ec%97%ac%eb%a6%84%ec%9d%b4%eb%8b%88%ea%b9%8c-%eb%b6%80%ec%82%b0-%eb%a8%b9%ed%82%b7-%eb%a6%ac%ec%8a%a4%ed%8a%b8-50/?utm_source=naver&utm_medium=partnership',
#   'org_link': 'https://www.gqkorea.co.kr/2022/06/08/%ec%97%ac%eb%a6%84%ec%9d%b4%eb%8b%88%ea%b9%8c-%eb%b6%80%ec%82%b0-%eb%a8%b9%ed%82%b7-%eb%a6%ac%ec%8a%a4%ed%8a%b8-50/?utm_source=naver&utm_medium=partnership',
#   'pDate': '2022-06-08 12:36:00',
#   'title': '꼭 먹어봐야 할 <b>부산</b> 먹킷 리스트 50'},
#  {'cnt': 99,
#   'description': '장소는 <b>부산</b> 토즈<b>서면</b>점으로 시간은 오후 1시부터 3시까지다. 예비창업자들이 실질적으로 필요로 하는 창업... 외식 프랜차이즈 대한곱창 관계자는 &quot;군자대한곱창은 소곱창 배달로 배달의 민족 <b>맛집</b> 랭킹에 등극되면서... ',
#   'link': 'https://n.news.naver.com/mnews/article/417/0000816216?sid=101',
#   'org_link': 'http://moneys.mt.co.kr/news/mwView.php?no=2022052215223341278',
#   'pDate': '2022-05-24 21:03:00',
#   'title': '다가오는 일상 회복, 예비 사장님들 어서 오세요'},
#  {'cnt': 100,
#   'description': '<b>부산 서면</b> 학원가를 중심으로는 작은 분식점들이 크게 늘어났습니다. 당시 500원 단위로 분식을 먹을 수 있는... 2010년대 이후부터는 SNS가 발달하면서, <b>맛집</b> 찾기 열풍이 입니다. 양보다 질, 먹는 데 돈을 아끼지 않는... ',
#   'link': 'https://n.news.naver.com/mnews/article/082/0001156625?sid=102',
#   'org_link': 'http://www.busan.com/view/busan/view.php?code=2022052016120836703',
#   'pDate': '2022-05-21 15:43:00',
#   'title': '[레코드 <b>부산</b>] ⑨ 맛은 잊었어도, 추억은 잊을 수 없는 그때 그 식당'},
#  {'cnt': 101,
#   'description': '지역 <b>맛집</b>으로 자리 잡아 현재 25평 매장에서 연간 7억원대 매출을 올리고 있다. 가맹점인 해운대점은 당초... <b>부산 서면</b>의 거리 일대. 사진/손원태기자 ◆상권에 나타난 빈익빈 부익부 심화 SK텔레콤의 빅데이터 분석... ',
#   'link': 'http://www.smedaily.co.kr/news/articleView.html?idxno=230190',
#   'org_link': 'http://www.smedaily.co.kr/news/articleView.html?idxno=230190',
#   'pDate': '2022-05-09 11:16:00',
#   'title': '코로나 팬데믹이 상권기준 바꿨다 직영보다 가맹·도심보다 골목 선호'},
#  {'cnt': 102,
#   'description': '트렌디한 <b>맛집</b>이 많아 젊은 고객이 주로 찾는 상권”이라며 “젊은 층도 코로나19에 민감하게 반응하며... 이에 앞서 aT가 펴낸 ‘2021 국내외 외식 트렌드 보고서’를 보면 서울 홍대, <b>부산 서면</b>, 대구 중앙로역... ',
#   'link': 'https://n.news.naver.com/mnews/article/025/0003188508?sid=101',
#   'org_link': 'https://www.joongang.co.kr/article/25064471',
#   'pDate': '2022-04-19 00:04:00',
#   'title': '2년새 매출 45% 급감…강남역 상권, 봄날 오나'},
#  {'cnt': 103,
#   'description': '유명 <b>맛집</b>에는 손님이 몰려 장사진을 이뤘다. 폐업 위기 딛고 새벽 영업 재개 &quot;문 닫을 생각 없어&quot; 이른바 2차... <b>부산</b>진구 <b>서면</b> 등 <b>부산</b> 도심 번화가 식당은 거리두기 해제 첫날부터 북적였다. <b>서면</b> 태화쇼핑 뒷골목의 한... ',
#   'link': 'https://n.news.naver.com/mnews/article/001/0013121591?sid=102',
#   'org_link': 'https://www.yna.co.kr/view/AKR20220418078451062?did=1195m',
#   'pDate': '2022-04-18 19:52:00',
#   'title': '&quot;아무 때나 오세요&quot; &quot;해제 기념 한잔&quot; 2년 만에 일상회복 웃음꽃(종합)'},
#  {'cnt': 104,
#   'description': '트렌디한 <b>맛집</b>들이 많이 있어 젊은 고객이 주로 유입되는 상권”이라며 “젊은 층도 코로나19에... 이에 앞서 aT가 펴낸 ‘2021 국내외 외식 트렌드 보고서’를 보면 서울 홍대, <b>부산 서면</b>, 대구 중앙로역, 광주... ',
#   'link': 'https://n.news.naver.com/mnews/article/025/0003188366?sid=101',
#   'org_link': 'https://www.joongang.co.kr/article/25064325',
#   'pDate': '2022-04-18 15:00:00',
#   'title': '코로나 2년, 강남역 매출 반토막…아메리카노 값은 78% 뛰었다'},
#  {'cnt': 105,
#   'description': '대부분 식당 좌석이 여유로웠고 <b>맛집</b>으로 유명한 곳 역시 대기 줄이 3분의 1밖에 되지 않았다. 일대에는... 반면 <b>부산</b>진구 <b>서면</b> 젊음의 거리는 전혀 다른 모습이었다. 평일 오후인데도 사람이 끊임 없이 오가고 인기... ',
#   'link': 'https://n.news.naver.com/mnews/article/658/0000005129?sid=102',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0300&key=20220324.33003006193',
#   'pDate': '2022-03-24 00:44:00',
#   'title': '외출객 늘자 <b>서면</b> 회복세…업체 빠져나간 <b>부산</b>역권 고전'},
#  {'cnt': 106,
#   'description': '여기는 지금 <b>부산 서면</b>에 있는 사미헌 갈비탕집 앞입니다. 식사를 하고 계신 손님들과 실시간 인터뷰... <b>부산</b>, 제주, 강릉 등 지방을 직접 돌아다니며 숨은 <b>맛집</b>과 명소를 소개하고, 서울 강남 한복판의 불 꺼진... ',
#   'link': 'https://n.news.naver.com/mnews/article/014/0004804345?sid=101',
#   'org_link': 'http://www.fnnews.com/news/202203161814263703',
#   'pDate': '2022-03-16 18:15:00',
#   'title': '재미·매출 多잡은 라이브11… 방송 켰다하면 빵빵 터진다 [11번가 예능...'},
#  {'cnt': 107,
#   'description': '멀리 있는 <b>맛집</b>에 직접 가지 않고 줄을 서지 않아도 간편식을 통해 음식을 맛볼 수 있어 소비자에게 인기가... <b>부산 서면</b>의 유명 한식당인 ‘사미헌’의 갈비탕 역시 간편식으로 재탄생해 쇼핑몰 마켓컬리의 대표... ',
#   'link': 'https://n.news.naver.com/mnews/article/658/0000004109?sid=101',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0200&key=20220311.22017002447',
#   'pDate': '2022-03-11 00:12:00',
#   'title': '<b>부산</b><b>맛집</b> 요리·고급 한식을 이 한 봉지에…간편식의 진화'},
#  {'cnt': 108,
#   'description': 'GS25는 지난 1월 압구정 퓨전 한식 <b>맛집</b> ‘호족반’과 협업해 ‘봉골레 칼국수’‘트러플 감자 베이컨... 실제 <b>부산 서면</b> 직영점에서는 직원 한 명이 5개 오토웍을 활용해 80인분의 닭갈비철판볶음밥 단체 주문을 1시간 만에... ',
#   'link': 'https://n.news.naver.com/mnews/article/024/0000073446?sid=101',
#   'org_link': 'https://www.mk.co.kr/economy/view/2022/156828',
#   'pDate': '2022-02-24 21:34:00',
#   'title': "한식의 ‘New Normal’...봉골레 칼국수·봇밥·맡김차림 '한식 <b>2</b>.0’"},
#  {'cnt': 109,
#   'description': "한 유명 온라인 숙박 예약 플랫폼에선 쏘타컬렉션 더 테라스가 <b>부산</b>의 '뷰 <b>맛집</b>'으로 소개되며 유명세를... 현재 경기도 평택에 880실, <b>부산 서면</b>에 400실, 강원도 양양에 415실 규모의 생활형숙박시설 개발을 위한 계약을... ",
#   'link': 'https://www.paxnetnews.com/articles/84049',
#   'org_link': 'https://www.paxnetnews.com/articles/84049',
#   'pDate': '2022-02-24 08:32:00',
#   'title': '[프롭테크 기업 열전] &quot;호텔 운영의 페러다임 변화 선도하겠다&quot;'},
#  {'cnt': 110,
#   'description': '윤 후보는 공식 선거운동 첫날(15일) 마지막 유세현장인 <b>부산 서면</b> 젊음의거리 유세에서 확연히 달라진... 온라인 커뮤니티에서는 “윤딩크” “무대체질” “어퍼컷 <b>맛집</b>” 등의 반응과 함께 이날까지도 세리모니 영상에... ',
#   'link': 'https://n.news.naver.com/mnews/article/016/0001952265?sid=100',
#   'org_link': 'http://news.heraldcorp.com/view.php?ud=20220217000236',
#   'pDate': '2022-02-17 10:31:00',
#   'title': '尹, ‘쭉뻗’ 접고 ‘어퍼컷’…지지층 ‘호응’'},
#  {'cnt': 111,
#   'description': "<b>부산</b> <b>부산</b>진구 <b>서면</b>에 위치한 KT&amp;G 상상마당 <b>부산</b> 2층에 위치한 파도블 매장 옆 '커스텀 슈즈 랩' 공간에서... <b>부산</b>이 원조이기 때문이라는 의미다. 사람들은 <b>맛집</b>을 가더라도 본점으로 모인다. 능력있고 개성있는 커스텀... ",
#   'link': 'https://www.nbntv.kr/news/articleView.html?idxno=273453',
#   'org_link': 'https://www.nbntv.kr/news/articleView.html?idxno=273453',
#   'pDate': '2022-02-16 20:38:00',
#   'title': '[다시 뛰는 100년 역사 <b>부산</b> 신발산업] (6)-<b>2</b> 커스텀 슈즈 청년작가 3인...'},
#  {'cnt': 112,
#   'description': "선보이고, <b>부산 서면</b>의 유명 마카롱 <b>맛집</b> '프띠르' 팝업 매장에서는 '딸기 요거트 조개롱', '민트초코 마카롱' 발로나 초코 타르트 등 다양한 맛의 타르트·마카롱을 제안한다. 서울 이대 베이글 <b>맛집</b>으로 오픈런은... ",
#   'link': 'http://www.ggilbo.com/news/articleView.html?idxno=896702',
#   'org_link': 'http://www.ggilbo.com/news/articleView.html?idxno=896702',
#   'pDate': '2022-02-16 19:08:00',
#   'title': '갤러리아타임월드, 새콤달콤 봄 디저트 세계'},
#  {'cnt': 113,
# ...
#   'org_link': 'http://www.yeongnam.com/mnews/newsview.do?mode=newsView&newskey=20130525.010130756120001',
#   'pDate': '2013-11-22 10:54:00',
#   'title': "['불황은 없다' 지역본사 프랜차이즈] 연탄돼지불고기 전문점‘봉구지..."},
#  {'cnt': 581,
#   'description': "' 고객들이 오는 30일까지 전국 번화가 9곳의 인기 <b>맛집</b> 및 멋집 90여곳에서 각종 인기 메뉴를 반값으로... 고객들은 서울 가로수길, 강남역·이태원·홍대·대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로, 대전 둔산... ",
#   'link': 'https://n.news.naver.com/mnews/article/014/0002909887?sid=105',
#   'org_link': 'http://www.fnnews.com/view?ra=Sent0901m_01A&corp=fnnews&arcid=201306220311042331104233&cDateYear=2013&cDateMonth=06&cDateDay=22&',
#   'pDate': '2013-06-22 03:12:00',
#   'title': 'SK텔 ‘T멤버십 ？’ <b>맛집</b>·멋집 반값 할인'},
#  {'cnt': 582,
#   'description': '인기 <b>맛집</b>·멋집의 인기 메뉴를 반값 할인해주는 행사를 진행한다. 서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로, 대전 둔산 등이 이벤트 혜택 적용 지역이며, 이벤트 참여... ',
#   'link': 'https://n.news.naver.com/mnews/article/005/0000562575?sid=101',
#   'org_link': 'http://news.kukinews.com/article/view.asp?page=1&gCode=kmi&arcid=0007299749&cp=nv',
#   'pDate': '2013-06-21 19:15:00',
#   'title': '[비즈파일] 삼성물산, 도하 메트로 프로젝트 중앙역사 건설공사 수주 外'},
#  {'cnt': 583,
#   'description': "' 고객들이 오는 30일까지 전국 번화가 9곳의 인기 <b>맛집</b> 및 멋집 90여곳에서 각종 인기 메뉴를 반값으로... 고객들은 서울 가로수길, 강남역·이태원·홍대·대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로, 대전 둔산... ",
#   'link': 'https://n.news.naver.com/mnews/article/014/0002909657?sid=105',
#   'org_link': 'http://www.fnnews.com/view?ra=Sent0901m_01A&corp=fnnews&arcid=201306220100211160012171&cDateYear=2013&cDateMonth=06&cDateDay=21&',
#   'pDate': '2013-06-21 16:49:00',
#   'title': 'SK텔 ‘T멤버십 ?’ <b>맛집</b>·멋집 반값 할인'},
#  {'cnt': 584,
#   'description': 'SK텔레콤(대표 하성민)의 ‘T멤버십 ?’ 가입고객은 오는 30일까지 열흘간 전국 번화가 9곳의 인기 <b>맛집</b>... 서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로, 대전 둔산이 이벤트 혜택... ',
#   'link': 'http://www.ajunews.com/kor/view.jsp?newsId=20130621000241',
#   'org_link': 'http://www.ajunews.com/kor/view.jsp?newsId=20130621000241',
#   'pDate': '2013-06-21 12:56:00',
#   'title': 'SKT, ‘T멤버십 ?’ 고객에 열흘간 ‘4배 혜택’ 쏜다'},
#  {'cnt': 585,
#   'description': '◇ SK텔레콤 직원들이 인기 <b>맛집</b>에서 반값 할인 혜택을 받을 수 있는 이벤트를 홍보하고 있다. ⓒSK텔레콤... 반값에 즐기수 있는 지역은 서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구... ',
#   'link': 'http://www.ebn.co.kr/news/n_view.html?id=611709',
#   'org_link': 'http://www.ebn.co.kr/news/n_view.html?id=611709',
#   'pDate': '2013-06-21 11:35:00',
#   'title': '‘T멤버십 눝’ 가입자, 번화가 <b>맛집</b> ‘반값’'},
#  {'cnt': 586,
#   'description': '인기 <b>맛집</b>·멋집 90여 곳에서 각종 인기 메뉴를 반값으로 할인 받을 수 있다. SK텔레콤은 무한포텐(for 10)Days... 이벤트 혜택 적용 지역은 서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구... ',
#   'link': 'https://n.news.naver.com/mnews/article/123/0002030577?sid=101',
#   'org_link': 'http://www.joseilbo.com/news/news_read.php?uid=186429&class=54',
#   'pDate': '2013-06-21 11:03:00',
#   'title': "SKT, 'T멤버십 ㄴㅜㅌ' 고객 열흘 간 4배 혜택 이벤트"},
#  {'cnt': 587,
#   'description': "SKT SK텔레콤(017670)은 'T멤버십 눝' 가입 고객을 대상으로 오는 30일까지 전국 번화가 9곳의 인기 <b>맛집</b>·멋집... 서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로, 대전 둔산이 이벤트... ",
#   'link': 'https://n.news.naver.com/mnews/article/366/0000131494?sid=105',
#   'org_link': 'http://biz.chosun.com/site/data/html_dir/2013/06/21/2013062101181.html',
#   'pDate': '2013-06-21 10:51:00',
#   'title': "SKT &quot;누+ㅌ'고객 대상 열흘간 반값 이벤트"},
#  {'cnt': 588,
#   'description': "SK텔레콤은 젊은층을 위한 멤버십 서비스인 'T멤버십 ?' 고객들에게 오는 30일까지 전국 번화가 9곳의 <b>맛집</b>... 이에 따라 고객들은 서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로... ",
#   'link': 'https://n.news.naver.com/mnews/article/014/0002909321?sid=105',
#   'org_link': 'http://www.fnnews.com/view?ra=Sent0901m_01A&corp=fnnews&arcid=201306210100209010011852&cDateYear=2013&cDateMonth=06&cDateDay=21&',
#   'pDate': '2013-06-21 10:27:00',
#   'title': 'SK텔레콤, ? 멤버십 고객에게 전국 번화가 반값할인 제공'},
#  {'cnt': 589,
#   'description': '9곳의 <b>맛집</b>·멋집 90여 곳에서 각종 인기 메뉴를 반값으로 할인 받을 수 있다. T멤버십 눝은 젊은 층의... 서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로, 대전 둔산이 이벤트 혜택... ',
#   'link': 'https://n.news.naver.com/mnews/article/109/0002559555?sid=105',
#   'org_link': 'http://www.osen.co.kr/article/G1109623392',
#   'pDate': '2013-06-21 10:07:00',
#   'title': "SKT, 'T멤버십 눝' 가입자에게 열흘간 혜택 쏜다"},
#  {'cnt': 590,
#   'description': "서울 가로수길, 강남역, 이태원, 홍대, 대학로, <b>부산 서면</b>, 광주 전남대, 대구 동성로, 대전 둔산이 이번 행사 대상 지역이다. 참여 제휴처는 '무한포텐days 반값 할인 제휴처'라고 적힌 깃발을 부착해 쉽게 알아볼 수... ",
#   'link': 'https://n.news.naver.com/mnews/article/277/0003027274?sid=105',
#   'org_link': 'http://www.asiae.co.kr/news/view.htm?idxno=2013062108401433364',
#   'pDate': '2013-06-21 09:09:00',
#   'title': "SKT, 'T멤버십 눝' 30일까지 인기<b>맛집</b> '반값할인'"},
#  {'cnt': 591,
#   'description': '시지 신매광장 <b>맛집</b>도 줄지어 나들이 제격 칠곡3지구는 ‘북구의 동성로’명성 북적북적 # 새로 떠오르는 곳... 주변 공간이 넓어 시원한 느낌을 주는 것은 <b>부산</b>의 <b>서면</b> 지하상가를 압도한다”면서 “마음에 드는 것은... ',
#   'link': 'http://www.yeongnam.com/mnews/newsview.do?mode=newsView&newskey=20130601.010020748190001',
#   'org_link': 'http://www.yeongnam.com/mnews/newsview.do?mode=newsView&newskey=20130601.010020748190001',
#   'pDate': '2013-06-01 08:36:00',
#   'title': '[y스페셜] 대구 젊음의 분출구를 가다'},
#  {'cnt': 592,
#   'description': '본점과 <b>부산 서면</b>점 그리고 대구백화점, 대백프라자 등에 입점해 있는데 올해는 판매처를 더욱 확대하는... 권 상무는 네이버에 자신의 블로그를 만들어 사업 이야기뿐만 아니라 <b>맛집</b>, 드라마 등 다양한 일상 이야기를... ',
#   'link': 'https://n.news.naver.com/mnews/article/014/0002882924?sid=101',
#   'org_link': 'http://www.fnnews.com/view?ra=Sent0601m_01A&corp=fnnews&arcid=201305170100174130009745&cDateYear=2013&cDateMonth=05&cDateDay=16&',
#   'pDate': '2013-05-16 17:14:00',
#   'title': '‘그 아버지에 그 딸’..당찬 부녀경영시대'},
#  {'cnt': 593,
#   'description': '이탈리안 파스타치킨 카페 ‘빠담빠담’이 지난 5일 <b>부산</b>광역시 <b>부산</b>진구 <b>서면</b>에 ‘빠담빠담 <b>서면</b>점’을... 업계에서도 ‘빠담빠담 센텀점’이 오픈한 지 3개월 만에 이색 치킨<b>맛집</b>으로 많은 인기를 누린 만큼 빠담빠담... ',
#   'link': 'https://n.news.naver.com/mnews/article/396/0000075952?sid=103',
#   'org_link': 'http://www.sportsworldi.com/Articles/LeisureLife/Article.asp?aid=20130410003510&OutUrl=naver',
#   'pDate': '2013-04-10 15:51:00',
#   'title': '‘빠담빠담’, <b>부산</b> 센텀점 이어 <b>부산</b> 번화가 ‘<b>서면</b>’ 진출'},
#  {'cnt': 594,
#   'description': "빠담빠담 <b>부산 서면</b>점 매장내부 모습 이탈리안 파스타치킨 카페 '빠담빠담'이 <b>부산 서면</b>점을 오픈했다고 8일... 또한 빠담빠담 센텀점이 오픈 3개월만에 이 지역 이색치킨 <b>맛집</b>으로 자리잡아 근처 직장인과 네티즌 사이에... ",
#   'link': 'https://n.news.naver.com/mnews/article/014/0002852660?sid=101',
#   'org_link': 'http://www.fnnews.com/view?ra=Sent1001m_01A&corp=fnnews&arcid=201304080100083590004498&cDateYear=2013&cDateMonth=04&cDateDay=08&',
#   'pDate': '2013-04-08 13:52:00',
#   'title': '파스타치킨 카페 ‘빠담빠담’ <b>부산 서면</b>점 오픈'},
#  {'cnt': 595,
#   'description': '▲서울의 중심은 명동, <b>부산</b>의 중심은 <b>서면</b> <b>부산</b> 지도를 펴놓고 보면 그 중심에는 <b>부산</b>진구가 있다. 그... 농심 호텔 앞에는 노천탕에서 무료로 족욕을 하며 여행의 피로를 풀 수 있고 주변에는 다양한 <b>맛집</b>들이 즐비하다.... ',
#   'link': 'https://n.news.naver.com/mnews/article/396/0000070576?sid=103',
#   'org_link': 'http://www.sportsworldi.com/Articles/LeisureLife/Article.asp?aid=20130317003005&OutUrl=naver',
#   'pDate': '2013-03-17 21:39:00',
#   'title': '<b>부산</b>을 벗겼다, 두얼굴의 <b>서면</b>이 드러났다'},
#  {'cnt': 596,
#   'description': "■집안 비법 계승·발전 '향토' <b>맛집</b><b>부산</b>에는 오랜 시간 서민들의 허기를 달래온 토속 <b>맛집</b>도 많다. 대표적인 곳이 <b>부산</b>진구 <b>서면</b>시장의 '송정3대국밥'이다. 1946년 고 송갑순 씨가 <b>부산</b> 연지시장에서 국밥 좌판을... ",
#   'link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0700&key=20130101.22034184239',
#   'org_link': 'http://www.kookje.co.kr/news2011/asp/newsbody.asp?code=0700&key=20130101.22034184239',
#   'pDate': '2013-01-01 07:48:00',
#   'title': '백년장수로 가는 <b>부산</b>의 맛'},
#  {'cnt': 597,
#   'description': '새벽시장 관계자는 &quot;<b>부산서면</b>점의 경우 월 매출 1억 원을 이상을 올리고 있다&quot;라고 말하면서,&quot;가맹점 창업을... 에 비슈라 관계자는 &quot;천안<b>맛집</b>으로 유명한 천안 에 비슈라와 수유<b>맛집</b>인 수유 에 비슈라 모두 회생... ',
#   'link': 'https://n.news.naver.com/mnews/article/076/0002293034?sid=101',
#   'org_link': 'http://sports.chosun.com/news/ntype.htm?id=201212280100176260014614&servicedate=20121228',
#   'pDate': '2012-12-28 15:39:00',
#   'title': "프랜차이즈업계 '고객과 소통'…화려함보다 솔직함이 통했다"},
#  {'cnt': 598,
#   'description': "구성은 '철권 6' 2대, '철권 6: BR' 5대, '철권 태그 토너먼트 <b>2</b> 언리미티드' 3대로, 가격은 ‘철권 6’ 이 300원... 춘하추동밀면의 밀면 맛있는 낙지볶음: 개미집 두 번째로 소개할 <b>서면</b>의 <b>맛집</b>은 <b>부산</b> 전역에 체인점을 두고... ",
#   'link': 'http://www.gamemeca.com/api/move.html?co_comp=naver_s&move_url=http%3A%2F%2Fwww.gamemeca.com%2Fnews%2Fspecial_move.html%3Fseq%3D1724',
#   'org_link': 'http://www.gamemeca.com/api/move.html?co_comp=naver_s&move_url=http%3A%2F%2Fwww.gamemeca.com%2Fnews%2Fspecial_move.html%3Fseq%3D1724',
#   'pDate': '2012-08-18 00:30:00',
#   'title': '[성지순례] 한국에서 가장 큰 오락실, <b>부산</b> 삼보게임센터'},
#  {'cnt': 599,
#   'description': '일본인 관광객 마타(27) 씨는 &quot;실버통역단 덕분에 <b>서면</b> 근처의 <b>맛집</b>과 쇼핑센터를 쉽게 찾을 수 있었다&quot;며... 실버통역단은 1호선 자갈치, 남포, 중앙, <b>부산</b>, <b>서면</b>, 노포 5개 역과 2호선 센텀시티, 해운대, 광안, 동백 4개역을... ',
#   'link': 'https://n.news.naver.com/mnews/article/082/0000344805?sid=102',
#   'org_link': 'http://news20.busan.com/news/newsController.jsp?newsId=20120616000026',
#   'pDate': '2012-06-16 07:45:00',
#   'title': "[시민기자 광장] 실버통역단 외국인 관광 길라잡이 '톡톡'"},
#  {'cnt': 600,
#   'description': '특급 호텔 요리사가 개발한 이태리 정통 스파게티를 1만 원대 이하의 저렴한 가격으로 맛볼 수 있는 <b>맛집</b>이... 파스타명작은 5월31일 석촌점 오픈에 이어 홍대점, <b>부산서면</b>점을 오픈할 예정이다. 파스타명작 관계자는... ',
#   'link': 'https://n.news.naver.com/mnews/article/008/0002850986?sid=101',
#   'org_link': 'http://www.mt.co.kr/view/mtview.php?type=1&no=2012053110513255296&outlink=1',
#   'pDate': '2012-05-31 15:53:00',
#   'title': '고급파스타 5900원? 고수들만 아는 ‘파스타명작’'},
#  {'cnt': 601,
#   'description': '특히, 이번 매장확장은 <b>부산</b>지역내 원정쇼핑객이 크게 증가하는 등 <b>부산</b>이 ‘제 <b>2</b> 의 쇼핑도시’로 급부상하는데 따른 공격적인 변신의 하나로, 전국백화점 4위이자 전통적인 쇼핑중심지인 <b>부산 서면</b>에 위치한... ',
#   'link': 'https://n.news.naver.com/mnews/article/112/0002291934?sid=102',
#   'org_link': 'http://biz.heraldm.com/common/redirect.jsp?category_id=010109010000&news_id=20120424001145',
#   'pDate': '2012-04-24 16:40:00',
#   'title': '“호텔이야? 백화점이야?” 롯데호텔<b>부산</b> 7000여㎡ 백화점 변신'},
#  {'cnt': 602,
#   'description': '특히 이번 매장확장은 <b>부산</b>지역 내 원정쇼핑객이 크게 증가하는 등 <b>부산</b>이 ‘제 <b>2</b> 의 쇼핑도시’로 급부상하는데 따른 공격적인 변신의 하나로 평가 받고 있다. 전국백화점 4위이자 전통적인 쇼핑중심지인 <b>부산 서면</b>에... ',
#   'link': 'https://n.news.naver.com/mnews/article/011/0002234250?sid=102',
#   'org_link': '',
#   'pDate': '2012-04-24 16:18:00',
#   'title': '롯데백화점 <b>부산</b> 본점, 대대적 매장 확충…비 영업공간 등 리뉴얼 ‘에...'},
#  {'cnt': 603,
#   'description': '쇼핑중심지인 <b>부산 서면</b>에 위치한 <b>부산</b>본점에 이번 상품기획(MD) 강화를 통해 경쟁력을 높이기 위해서라고... 지역 유명 <b>맛집</b>을 발굴하고 푸드코트 경쟁력을 강화하기 위해 1947년 <b>부산</b> 중구 보수동에서 창업한 이후... ',
#   'link': 'https://n.news.naver.com/mnews/article/015/0002679256?sid=102',
#   'org_link': 'http://www.hankyung.com/news/app/newsview.php?aid=201204242783h',
#   'pDate': '2012-04-24 10:13:00',
#   'title': "[<b>부산</b>·경남]<b>부산</b>롯데백화점,'호텔 속 백화점' 첫선"},
#  {'cnt': 604,
#   'description': "지난 6일 여행 블로그로 이름깨나 날린다는 블로거 '푸른솔'의 '여행 블로그 강좌(사진)'가 <b>부산 서면</b>의 한... 그리고 <b>맛집</b>도 있을 테다. 귀찮게 여겨질지도 모르겠지만 지난 여행을 정리하는 좋은 계기도 된다. 이 또한... ",
#   'link': 'https://n.news.naver.com/mnews/article/082/0000323991',
#   'org_link': 'http://news20.busan.com/news/newsController.jsp?newsId=20120112000026',
#   'pDate': '2012-01-12 08:03:00',
#   'title': "[일상탈출] 파워블로거 '푸른솔'의 여행 블로그 강좌"},
#  {'cnt': 605,
#   'description': "“포털사이트에서 ‘<b>부산 서면 맛집</b>’이라고 검색하면 '블루케찹'이 제일 위쪽에 뜰 정도로 <b>맛집</b>으로... 본사는 이런 약점을 개선하기 위해 지하와 2층, 심지어는 5층이나 <b>2</b>~3층으로 구성된 복층 매장으로 오픈가능... ",
#   'link': 'https://n.news.naver.com/mnews/article/008/0002633419?sid=101',
#   'org_link': 'http://www.moneytoday.co.kr/view/mtview.php?type=1&no=2011101512175967758&outlink=1',
#   'pDate': '2011-10-16 20:33:00',
#   'title': '20대 젊은 소비자들 신개념 감성주점에 열광하다'},
#  {'cnt': 606,
#   'description': "<b>맛집</b>, 관광지 등은 물론이고 '핫 이슈'까지 시민기자와 상근기자가 지역의 희로애락을 낱낱이 보여드립니다.... ⓒ 조을영 <b>부산 서면</b>시장 손칼국수가 말해주는 '누른국수의 미래' 하여간 누른국수를 보니 문득 떠오르는... ",
#   'link': 'https://n.news.naver.com/mnews/article/047/0001983950?sid=103',
#   'org_link': 'http://www.ohmynews.com/NWS_Web/view/at_pg.aspx?CNTN_CD=A0001597358',
#   'pDate': '2011-07-27 14:15:00',
#   'title': '대구음식, 망신스러워서 못 권하겠네'},
#  {'cnt': 607,
#   'description': "핵심 상권의 골목길까지 상세히 보여주는 고화질 지도가 등장하며 '뜨는 <b>맛집</b>·까페' 랭킹 정보, 사진 등... LTE 커버리지에 포함된 서울(광화문), <b>부산</b>(<b>서면</b>), 광주(전남대) 각 지역에서 휴대폰을 활용해 화상으로... ",
#   'link': 'https://n.news.naver.com/mnews/article/277/0002631535?sid=105',
#   'org_link': 'http://www.asiae.co.kr/news/view.htm?idxno=2011063014012616514',
#   'pDate': '2011-06-30 15:40:00',
#   'title': "'LTE'가 이끌 혁신적 통신라이프 키워드는..'영상'"},
#  {'cnt': 608,
#   'description': "TV <b>맛집</b> 정보 프로그램의 제작 과정을 고발한 다큐멘터리 영화 '트루맛쇼'가 개봉 이후 관객들의 높은... 상영관수 확대 요청이 이어지면서 8일 CGV 강변 및 <b>부산 서면</b> 등에 개봉관을 추가한 상태다. 하지만 CGV 강변의 경우... ",
#   'link': 'https://m.entertain.naver.com/article/009/0002480808',
#   'org_link': 'http://star.mk.co.kr/new/view.php?mc=ST&no=364058&year=2011',
#   'pDate': '2011-06-08 17:20:00',
#   'title': '`트루맛쇼`, 상영관 늘었지만 뭔가 아쉽다'},
#  {'cnt': 609,
#   'description': '특히 <b>부산 서면</b>시장에 있는 돼지국밥 골목은 피난민들의 애환과 향수가 그대로 남아 있는 곳이다. 이 골목이... 이미 송정돼지국밥의 맛은 수많은 <b>맛집</b> 프로그램에서 앞 다퉈 소개했을 정도로 정평이 나 있다. 65년의... ',
#   'link': 'http://www.dailian.co.kr/news/news_view.htm?id=217962&sc=naver&kind=menu_code&keys=81',
#   'org_link': 'http://www.dailian.co.kr/news/news_view.htm?id=217962&sc=naver&kind=menu_code&keys=81',
#   'pDate': '2010-09-02 14:40:00',
#   'title': '65년 전통 송정돼지국밥에서 추억의 맛을 찾는다!'},
#  {'cnt': 610,
#   'description': '이런 집을 선전하고 착한 <b>맛집</b>이 장사가 잘되고 사람들에게 인기가 많으면 나쁜 <b>맛집</b>들도 최저임금을 지키지 않겠는가?&quot; (최고운) &quot;<b>서면</b> 일대에서 뮤직비디오를 촬영하고 싶다. <b>부산</b>지역에서 문화 활동을 하고 있는... ',
#   'link': 'https://n.news.naver.com/mnews/article/047/0001969843?sid=102',
#   'org_link': 'http://www.ohmynews.com/NWS_Web/view/at_pg.aspx?CNTN_CD=A0001407371',
#   'pDate': '2010-06-28 21:10:00',
#   'title': '최저임금 지키는 착한 <b>맛집</b>, 어디 없나요'},
#  {'cnt': 611,
#   'description': '이미 <b>부산 서면</b>에 토마토아저씨 가맹점이 자리를 잡고 있어 브랜드 인지도가 있는데다 아기자기하고 편안한 인테리어와 친절한 서비스로 블로그, 카페 등 온라인 커뮤니티에서 <b>맛집</b>으로 이름이 알려져 있기... ',
#   'link': 'https://n.news.naver.com/mnews/article/018/0002242594?sid=102',
#   'org_link': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02548566592937760',
#   'pDate': '2010-04-19 18:32:00',
#   'title': '<b>부산</b>박람회 열기 사업설명회로 이어가'},
#  {'cnt': 612,
#   'description': '14일 <b>부산</b>시 <b>부산</b>진구 <b>서면</b> 롯데호텔 정문 맞은편. 병원건물마다 한창 간판 개편작업이 진행 중이다.... 의료관광을 추진하는 의료기관，<b>맛집</b>，숙박시설과 교통안내 정보 등이 담긴다. <b>부산</b>시티투어 코스에 대한 안내와... ',
#   'link': 'https://n.news.naver.com/mnews/article/015/0002127300?sid=102',
#   'org_link': 'http://www.hankyung.com/news/app/newsview.php?aid=2009091377811',
#   'pDate': '2009-09-14 18:31:00',
#   'title': '[도시 경쟁력을 높여라-<b>부산</b>] <b>부산</b>, 의료관광 컨벤션의 메카로 뜬다'},
#  {'cnt': 613,
#   'description': '장소는 롯데시네마 <b>부산</b>점(<b>서면</b>)과 동래점이며 9월22일 오후 6시부터 매진될 때까지 표를 구입할 수 있다.... 숙소, <b>맛집</b>, 볼거리 해운대와 남포동으로 나뉘어 영화제가 진행되는 만큼 각각의 <b>맛집</b>과 볼거리, 숙소들을 미리... ',
#   'link': 'https://m.entertain.naver.com/article/140/0000012184',
#   'org_link': 'http://www.cine21.com/Index/magazine.php?mm=005001001&mag_id=53087',
#   'pDate': '2008-09-30 08:00:00',
#   'title': '[PIFF2008] 실용 정보: 잠깐! <b>부산</b>행 낭만기차 타기 전에 체크하세요'},
#  {'cnt': 614,
#   'description': "그 '애초'를 찾아 <b>부산 서면</b> 영광도서 건너편의 골목길을 더듬어 '사리원냉면' 집에 들렀다. 이 집 냉면 맛은... 근년 여러 블로그에서 <b>부산</b>의 <b>맛집</b>으로 이곳을 소개하고 있기 때문. 이 집, 면발이 좋다. 평양식은 메밀... ",
#   'link': 'https://n.news.naver.com/mnews/article/082/0000164992?sid=103',
#   'org_link': 'http://www.busanilbo.com/news2000/html/2008/0124/0L0020080124.1038161918.html',
#   'pDate': '2008-01-24 11:57:00',
#   'title': "[이집에 가면]<b>서면</b> 영광도서 맞은편 골목 '사리원 냉면'"},
#  {'cnt': 615,
#   'description': '<b>부산</b> 최대의 번화가인 <b>서면</b>로터리 북서쪽과 남쪽에는 각각 영광도서와 동보서적이 있다. 그리 멀리 떨어져... 영광도서 주변엔 사무용 빌딩과 중년이 자주 찾는 <b>맛집</b> 등이 밀집한 반면 동보서적은 주변에 영화관, 대형... ',
#   'link': 'https://n.news.naver.com/mnews/article/020/0000376866?sid=103',
#   'org_link': 'http://www.donga.com/fbin/output?n=200611250127',
#   'pDate': '2006-11-25 06:17:00',
#   'title': '[우리 마을 베스트셀러]<b>부산</b> 번화가 <b>서면</b>로터리에는'},
#  {'cnt': 616,
#   'description': '<b>부산</b> 진구 <b>서면</b>, 태화 백화점 벽면의 대형 전광 판(사진1)처럼, 도시가 계획된 디자인으로 도배될수록... 선배가 인도한 집은 24년 된 소문난 <b>맛집</b>. 소줏잔이 몇 잔 돌았을까. 주인 아줌마는 우리와 술잔을 주고받으며 자신... ',
#   'link': 'https://n.news.naver.com/mnews/article/021/0000037632?sid=103',
#   'org_link': '',
#   'pDate': '2003-07-18 13:15:00',
#   'title': '&lt;한국 도시문화 탐험기&gt;(4)찬란했던 ‘민주 <b>부산</b>’의 숨결은 어디에…'}]

# %%
# 해당 데이터에서, 기사 내용인 , message 부분의 값 추출 작업. 
# 임시 저장 문자열
message = ""
# data = [{딕션너리1},{딕션너리2},{딕션너리3},...]
for item in data:
  # if "message" in item.keys():
  if "description" in item.keys():
    # (\w : 문자, 숫자 의미 ) 앞에 ^(not) 가 아닌 것은 모두 -> 공백으로 변경함.
    # 하나의 임시 메세지 문자열 변수에 담기
    message = message + re.sub(r"[^\w]"," ", item["description"]) + ""
    # message = message + re.sub(r"[^\w]"," ", item["message"]) + ""
message
# Out:
# '이 회사의 모회사인 애니플러스도 서울 합정동과  b 부산 서면  b  등에 일본 애니메이션과 협업해 굿즈를    이은희 인하대 소비자학과 교수는  돈키호테에서 이색적인 제품을 찾거나 일식  b 맛집  b 을 발굴하는 등 색다르게    강남역  일상비일상의틈 과  b 부산 서면  b   일상의틈  매장에 중소기업 제품 판매 공간을 마련했다고 2일    이용자가 원하는 조건의 장소를 대화형식으로 입력하면 개인의 취향과 라이프스타일에 맞는  b 맛집  b   카페    인근  b 맛집  b 인  이수가 본점 과  카린지 amp 린가네 스낵바 와 협업한 상품을 선보인다  기존  강릉편 1탄  과    스타필드점   b 부산 서면  b 점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다  이번 협업    스타필드점   b 부산 서면  b 점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다  이번 협업    인근  b 맛집  b 인  이수가 본점 과  카린지 amp 린가네 스낵바 와 협업한 상품을 선보인다  기존  강릉편 1탄  과  충청도    론칭 이후 팬츠 누적 판매량만 500만장에 달하는 등  남성 팬츠  b 맛집  b   브랜드로 익숙하다  이번 다니엘    스타필드점   b 부산 서면  b 점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다  이번 협업    스타필드점   b 부산 서면  b 점 등 8개의 오프라인 매장과 인근 카페 및 소품숍 31곳이 함께한다  이번 협업    커뮤니티 가입 회원들은 방문 후기  백화점 이용 TIP  인근  b 맛집  b  정보 등을 공유하며 신세계와 함께한 다양한 일상과    야당 일각에선  지역  b 맛집  b  소개  계획이 세워진 것으로 알려져 찬반 여론이 대립했다  16일    같은 날 오후 4 6시  b 부산 서면  b  동천로 일대에서는 정권퇴진 b 부산  b 시민행동 주최로  28차 정권 파면 시민대회 가 실시됐다     기존 판매했던 점포들에 서울 지역 3개점을 더했으며   b 부산서면  b 중앙점에서도 해당 상품을 만나볼 수 있다     실력을 검증받은 유명 셰프를 비롯한 전국구  b 맛집  b 과의 협업도 늘리고 있다  실제로 쓱닷컴은 최근  주서빈    해외유학과 이민을 위한 IELTS 국제 영어 시험  전문 교육 기관인 렉시스어학원이 서울 강남과  b 부산 서면  b 에    캠퍼스 건너편에는 다양한  b 맛집  b 과 여유롭게 산책할 수 있는 연트럴파크가 자리 잡고 있어 홍대신촌    스시 고우  b 서면  b 에 위치한 숨은  b 맛집  b 으로  가격 대비 높은 퀄리티의 오마카세를 제공한다  합리적인 가격으로 고급 오마카세를 경험할 수 있으며  런치 오마카세가 특히 인기 있다  위치   b 부산 서면  b  추천 메뉴  런치 오마카세     b 부산 서면  b 은 다양한 놀거리와 핫플레이스가 모여 있는 대표적인 번화가다  낮에는 쇼핑과 카페 투어를    디저트  b 맛집  b 도 많아 SNS에 업로드하기 좋은 사진을 남길 수 있다   b 2  b    b 서면  b  롯데백화점  amp  전자상가 쇼핑을 좋아하는    입구  b 맛집  b   메밀씨앗호떡  등을 포함해 다양한 특산품을 대거 선보일 예정이다  롯데몰 김해점은 신규     b 부산  b 에서는  b 서면  b 과 센텀시티에 이어 세 번째로 선보이는 매장으로  프리미엄 수제 버거에 대한 관심이 높은     b 맛집  b   전통방식 보양 미역국 대표 보양식 미역국은 생일을 기념해 먹는 음식이다  칼슘과 아이오딘이 많아 피를 맑게 하고  혈액순환을 촉진하는 헬스 푸드이자  특별한 날 대접받는 듯한 느낌도 준다  2015년  b 부산 서면  b 에    그래서 장아찌만 잘해도 그리 특별한 것 없는 백반집이  b 맛집  b 으로 소문난다  장아찌의 역할은 밥 먹기에 좋은      팔미분식    b 부산 서면  b 의 밤낮을 오랜 시간 지켜온 집이다  다양한 분식을 파는데 특히 충무김밥이 본향     b 부산  b 에 자리한 여러 곳의 돼지국밥  b 맛집  b 을 돌아다니며 다양한 돼지국밥을 맛보고 즐기는 것을 추천한다   b 서면  b 향토음식특화거리  송정3대국밥  식당 정보  송정3대국밥  1946년 개업해 지금까지  b 부산  b 의 대표 국밥    현재  b 부산  b  최대 도심인  b 부산  b 진구  b 서면  b  개발  1998년  b 부산  b 시 청사 이전 등으로 원도심은 쇠퇴를 시작했다     토론회에서는 관광객 이동 편의를 위해 원도심 관광셔틀버스 도입과 함께  지역 명소와  b 맛집  b 을 포함한 통합    현장상황관리관을 파견하는 12곳은 서울 이태원 홍대 명동 성수동 건대와  b 부산 서면  b   대구 동성로  대전    연세로  발산역  문래동  b 맛집  b 거리  신림역  샤로수길  논현역 등 인파 밀집이 예상되는 서울 시내 15개    연세로  발산역  문래동  b 맛집  b 거리  신림역  샤로수길  논현역 등 11개구 15곳이다  시는 이들 지역을    행안부는 인파밀집도가 높을 곳으로 예측되는 서울 이태원 홍대 명동 성수동 건대 등   b 부산 서면  b   대구    은하수  b 맛집  b  거리 참여 업체 27곳에서는 10  할인 행사를 진행해 많은 호응을 얻었다   b 부산  b 광역시  b 부산  b 진구 소상공인연합회 관계자는  quot 이번 축제를 통해 소상공인 간의 협력을 증진하고  b 서면  b  골목상권 활성화에 기여할 수    은하수  b 맛집  b  거리 참여 업체 27곳에서는 10  할인 행사를 진행한다   b 부산  b 광역시  b 부산  b 진구 소상공인연합회 관계자는  quot 이번 축제를 통해 소상공인 간의 연대감을 강화하고  b 서면  b  골목상권을 활성화할 것 quot 이라며  quot 소상공인에게    펫프렌들리ㆍ뷰  b 맛집  b ㆍ스마트 오피스까지   다양한 콘셉트로 차별화 꾀해 코로나19 이후 수익성이 악화한    SPC가 운영하는 또 다른 카페 브랜드 파스쿠찌도 4월  b 부산 서면  b 점과 광안리점에 젤라토 메뉴를 특화한 매장을    전국 라멘  b 맛집  b 으로는 경기 분당 서현 유타로  일산동구 계단라멘  의정부 사쿠라멘  수원 팔달구 키와마루아지  안양 쿠시카츠 쿠마  양산 무라   b 부산 서면  b  칸다소바   b 부산  b  해운대 나가하마만게츠   b 부산 서면  b  친치쿠린    모루과자점   b 부산 서면  b  쇼쿠팡   b 부산  b  동래 밀한줌  남천동 무슈뱅상   b 서면  b  아티성블렁제리빵빵빵  태종대 하버커피  동래 솦크렘샵  대구 삼송빵집  대구 대명동 프라리네  대구 동성로 근대골목단팥빵  대구 달서    미용봉사에 참여하는 미용사들은  b 부산  b 진구  b 서면  b 의 유명 미용실에서 현역으로 일하고 있는 베테랑들이다     평소 노을이 예쁘기로 입소문 나면서 환자나 간병 보호자들이 자주 찾아  노을 b 맛집  b  으로도 알려진 병원    미용봉사에 참여하는 미용사들은  b 부산  b 진구  b 서면  b 의 유명 미용실에서 현역으로 일하고 있는 베테랑들이다     평소 노을이 예쁘기로 입소문 나면서 환자나 간병 보호자들이 자주 찾아  노을 b 맛집  b  으로도 알려진 병원    미용봉사에 참여하는 미용사들은  b 부산  b 진구  b 서면  b 의 유명 미용실에서 현역으로 일하고 있는 베테랑들이다     평소 노을이 예쁘기로 입소문 나면서 환자나 간병 보호자들이 자주 찾아  노을 b 맛집  b  으로도 알려진 병원 옥상에서    타코  b 맛집  b  으로 큰 인기를 끌고 있다  포테토칩 올디스타코맛은 포테토칩에 소고기와 치즈 풍미  라임의    서이브는  홍대1호점   b 부산서면  b 태화점  대구동성로점 총 3곳에서 팬미팅을 진행할 예정이다 그는 전국 35개 체인점의 오너로  b 부산 서면  b 에 위치한  춘일  오마카세 대표이기도 하다 대구에는  귀신짬뽕    지역  b 맛집  b 으로 유명한 창업 동문들도 활발히 활동하고 있다  현대그린푸드  삼성웰스토리  한화리조트 등    서울 물회  b 맛집  ...

# %%
# 품사 태깅, Okt 패키지 사용하기. 
nlp = Okt()
message_N = nlp.nouns(message)
message_N
# Out:
# ['이',
#  '회사',
#  '모회사',
#  '애니플러스',
#  '서울',
#  '합정동',
#  '부산',
#  '서면',
#  '등',
#  '일본',
#  '애니메이션',
#  '협업',
#  '굿',
#  '를',
#  '이은희',
#  '인하대',
#  '소비자',
#  '학과',
#  '교수',
#  '돈키호테',
#  '이색',
#  '제품',
#  '일식',
#  '맛집',
#  '발굴',
#  '등',
#  '강남역',
#  '일상',
#  '비일',
#  '상의',
#  '틈',
#  '과',
#  '부산',
#  '서면',
#  '일상',
#  '틈',
#  '매장',
#  '중소기업',
#  '제품',
#  '판매',
#  '공간',
#  '마련',
#  '이용자',
#  '조건',
#  '장소',
#  '화형식',
#  '입력',
#  '개인',
#  '취향',
#  '라이프스타일',
#  '맛집',
#  '카페',
#  '인근',
#  '맛집',
#  '인',
#  '이수',
#  '본점',
#  '과',
#  '카린',
#  '린',
#  '스낵바',
#  '협업',
#  '상품',
#  '기존',
#  '강릉',
#  '편',
#  '과',
#  '스타',
#  '필드',
#  '점',
#  '부산',
#  '서면',
#  '점',
#  '등',
#  '개',
#  '오프라인',
#  '매장',
#  '인근',
#  '카페',
#  '및',
#  '소품',
#  '숍',
#  '곳',
#  '이번',
#  '협업',
#  '스타',
#  '필드',
#  '점',
#  '부산',
#  '서면',
#  '점',
#  '등',
#  '개',
#  '오프라인',
#  '매장',
#  '인근',
#  '카페',
#  '및',
#  '소품',
#  '숍',
#  '곳',
#  '이번',
#  '협업',
#  '인근',
#  '맛집',
#  '인',
#  '이수',
#  '본점',
#  '과',
#  '카린',
#  '린',
#  '스낵바',
#  '협업',
#  '상품',
#  '기존',
#  '강릉',
#  '편',
#  '과',
#  '충청도',
#  '론칭',
#  '이후',
#  '팬츠',
#  '누적',
#  '판매량',
#  '달',
#  '등',
#  '남성',
#  '팬츠',
#  '맛집',
#  '브랜드',
#  '이번',
#  '다니엘',
#  '스타',
#  '필드',
#  '점',
#  '부산',
#  '서면',
#  '점',
#  '등',
#  '개',
#  '오프라인',
#  '매장',
#  '인근',
#  '카페',
#  '및',
#  '소품',
#  '숍',
#  '곳',
#  '이번',
#  '협업',
#  '스타',
#  '필드',
#  '점',
#  '부산',
#  '서면',
#  '점',
#  '등',
#  '개',
#  '오프라인',
#  '매장',
#  '인근',
#  '카페',
#  '및',
#  '소품',
#  '숍',
#  '곳',
#  '이번',
#  '협업',
#  '커뮤니티',
#  '가입',
#  '회원',
#  '방문',
#  '후기',
#  '백화점',
#  '이용',
#  '인근',
#  '맛집',
#  '정보',
#  '등',
#  '공유',
#  '신세계',
#  '일상',
#  '야당',
#  '일각',
#  '지역',
#  '맛집',
#  '소개',
#  '계획',
#  '것',
#  '찬반',
#  '여론',
#  '대립',
#  '날',
#  '오후',
#  '부산',
#  '서면',
#  '동천로',
#  '일대',
#  '정권',
#  '퇴진',
#  '부산',
#  '시민행동',
#  '주최',
#  '차',
#  '정권',
#  '파면',
#  '시민',
#  '대회',
#  '실시',
#  '기존',
#  '판매',
#  '점포',
#  '서울',
#  '지역',
#  '개점',
#  '부산',
#  '서면',
#  '중앙',
#  '점',
#  '해당',
#  '상품',
#  '나볼',
#  '수',
#  '실력',
#  '검증',
#  '유명',
#  '셰프',
#  '비롯',
#  '전국구',
#  '맛집',
#  '협업',
#  '실제',
#  '쓱',
#  '최근',
#  '서빈',
#  '해외',
#  '유학',
#  '이민',
#  '위',
#  '국제',
#  '영어',
#  '시험',
#  '전문',
#  '교육',
#  '기관',
#  '렉시스',
#  '학원',
#  '서울',
#  '강남',
#  '부산',
#  '서면',
#  '캠퍼스',
#  '건너편',
#  '맛집',
#  '과',
#  '산책',
#  '수',
#  '트럴',
#  '파크',
#  '자리',
#  '잡고',
#  '홍대',
#  '신촌',
#  '스시',
#  '서면',
#  '위치',
#  '맛집',
#  '가격',
#  '대비',
#  '퀄리티',
#  '마카',
#  '세',
#  '제공',
#  '합리',
#  '가격',
#  '고급',
#  '마카',
#  '세',
#  '경험',
#  '수',
#  '런치',
#  '마카',
#  '세',
#  '인기',
#  '위치',
#  '부산',
#  '서면',
#  '추천',
#  '메뉴',
#  '런치',
#  '마카',
#  '세',
#  '부산',
#  '서면',
#  '은',
#  '놀',
#  '거리',
#  '핫',
#  '레이스',
#  '대표',
#  '번화가',
#  '낮',
#  '쇼핑',
#  '카페',
#  '투어',
#  '디저트',
#  '맛집',
#  '도',
#  '업로드',
#  '사진',
#  '수',
#  '서면',
#  '롯데',
#  '백화점',
#  '전자',
#  '상가',
#  '쇼핑',
#  '입구',
#  '맛집',
#  '메밀',
#  '씨앗',
#  '호떡',
#  '등',
#  '포함',
#  '특산',
#  '품',
#  '대거',
#  '예정',
#  '롯데',
#  '김해',
#  '점',
#  '신규',
#  '부산',
#  '서면',
#  '과',
#  '센텀시티',
#  '세',
#  '번',
#  '매장',
#  '프리미엄',
#  '수제',
#  '버거',
#  '대한',
#  '관심',
#  '맛집',
#  '전통',
#  '방식',
#  '보양',
#  '미역국',
#  '대표',
#  '보양식',
#  '미역국',
#  '생일',
#  '기념',
#  '음식',
#  '칼슘',
#  '아이오딘',
#  '피',
#  '혈액',
#  '순환',
#  '촉진',
#  '헬스',
#  '푸드',
#  '이자',
#  '날',
#  '듯',
#  '느낌',
#  '부산',
#  '서면',
#  '장아찌',
#  '것',
#  '집',
#  '맛집',
#  '장아찌',
#  '역할',
#  '밥',
#  '먹기',
#  '미분',
#  '부산',
#  '서면',
#  '의',
#  '밤낮',
#  '시간',
#  '온',
#  '집',
#  '분식',
#  '충무김밥',
#  '본향',
#  '부산',
#  '자리',
#  '여러',
#  '곳',
#  '돼지국밥',
#  '맛집',
#  '돼지국밥',
#  '것',
#  '추천',
#  '서면',
#  '향토음식',
#  '특',
#  '거리',
#  '송정',
#  '국밥',
#  '식당',
#  '정보',
#  '송정',
#  '국밥',
#  '개업',
#  '지금',
#  '부산',
#  '의',
#  '대표',
#  '국밥',
#  '현재',
#  '부산',
#  '최대',
#  '도심',
#  '부산',
#  '진구',
#  '서면',
#  '개발',
#  '부산',
#  '시',
#  '청사',
#  '이전',
#  '등',
#  '도심',
#  '쇠퇴',
#  '시작',
#  '토론회',
#  '관광객',
#  '이동',
#  '편의',
#  '위해',
#  '도심',
#  '관광',
#  '셔틀버스',
#  '도입',
#  '지역',
#  '명소',
#  '맛집',
#  '포함',
#  '통합',
#  '현장',
#  '상황',
#  '관리',
#  '관',
#  '파견',
#  '곳',
#  '서울',
#  '이태원',
#  '홍대',
#  '명동',
#  '성수동',
#  '건대',
#  '부산',
#  '서면',
#  '대구',
#  '동성로',
#  '대전',
#  '연세',
#  '발산역',
#  '문래동',
#  '맛집',
#  '거리',
#  '신림역',
#  '샤',
#  '길',
#  '논현역',
#  '등',
#  '인파',
#  '밀집',
#  '예상',
#  '서울',
#  '시내',
#  '개',
#  '연세',
#  '발산역',
#  '문래동',
#  '맛집',
#  '거리',
#  '신림역',
#  '샤',
#  '길',
#  '논현역',
#  '등',
#  '개구',
#  '곳',
#  '시',
#  '이',
#  '지역',
#  '행안부',
#  '인파',
#  '밀',
#  '집도',
#  '곳',
#  '예측',
#  '서울',
#  '이태원',
#  '홍대',
#  '명동',
#  '성수동',
#  '건대',
#  '등',
#  '부산',
#  '서면',
#  '대구',
#  '은하수',
#  '맛집',
#  '거리',
#  '참여',
#  '업체',
#  '곳',
#  '할인',
#  '행사',
#  '진행',
#  '호응',
#  '부산',
#  '광역시',
#  '부산',
#  '진구',
#  '상공',
#  '연합',
#  '회',
#  '관계자',
#  '이번',
#  '축제',
#  '통해',
#  '소상',
#  '공인',
#  '간의',
#  '협력',
#  '증진',
#  '서면',
#  '골목',
#  '상권',
#  '활성화',
#  '기여',
#  '수',
#  '은하수',
#  '맛집',
#  '거리',
#  '참여',
#  '업체',
#  '곳',
#  '할인',
#  '행사',
#  '진행',
#  '부산',
#  '광역시',
#  '부산',
#  '진구',
#  '상공',
#  '연합',
#  '회',
#  '관계자',
#  '이번',
#  '축제',
#  '통해',
#  '소상',
#  '공인',
#  '간의',
#  '대감',
#  '서면',
#  '골목',
#  '상권',
#  '활성화',
#  '것',
#  '라며',
#  '상공',
#  '펫프렌들리',
#  '뷰',
#  '맛집',
#  '스마트',
#  '오피스',
#  '콘셉트',
#  '차별',
#  '코로나',
#  '이후',
#  '수익',
#  '악화',
#  '운영',
#  '또',
#  '다른',
#  '카페',
#  '브랜드',
#  '파스쿠찌',
#  '부산',
#  '서면',
#  '점',
#  '광안',
#  '리점',
#  '젤라토',
#  '메뉴',
#  '특화',
#  '매장',
#  '전국',
#  '라멘',
#  '맛집',
#  '경기',
#  '분당',
#  '서현',
#  '유타',
#  '일산동구',
#  '계단',
#  '라멘',
#  '의정부',
#  '사쿠라',
#  '수원',
#  '팔달구',
#  '키',
#  '마루아',
#  '안양',
#  '쿠시카츠',
#  '쿠마',
#  '양산',
#  '무',
#  '부산',
#  '서면',
#  '칸',
#  '다소',
#  '바',
#  '부산',
#  '해운대',
#  '하마',
#  '츠',
#  '부산',
#  '서면',
#  '모루',
#  '과자',
#  '점',
#  '부산',
#  '서면',
#  '쇼',
#  '쿠팡',
#  '부산',
#  '동래',
#  '밀',
#  '줌',
#  '남천동',
#  '무슈',
#  '뱅',
#  '서면',
#  '아티',
#  '블렁',
#  '제리',
#  '빵빵',
#  '빵',
#  '태종대',
#  '하버',
#  '커피',
#  '동래',
#  '솦크렘샵',
#  '대구',
#  '송',
#  '빵집',
#  '대구',
#  '대명동',
#  '프라',
#  '리',
#  '대구',
#  '동성로',
#  '근대',
#  '골목',
#  '단팥빵',
#  '대구',
#  '달',
#  '미용',
#  '봉사',
#  '참여',
#  '미용사',
#  '부산',
#  '진구',
#  '서면',
#  '의',
#  '유명',
#  '미용실',
#  '현역',
#  '일',
#  '베테',
#  '평소',
#  '노을',
#  '입',
#  '소문',
#  '환자',
#  '간병',
#  '보호자',
#  '자주',
#  '노을',
#  '맛집',
#  '병원',
#  '미용',
#  '봉사',
#  '참여',
#  '미용사',
#  '부산',
#  '진구',
#  '서면',
#  '의',
#  '유명',
#  '미용실',
#  '현역',
#  '일',
#  '베테',
#  '평소',
#  '노을',
#  '입',
#  '소문',
#  '환자',
#  '간병',
#  '보호자',
#  '자주',
#  '노을',
#  '맛집',
#  '병원',
#  '미용',
#  '봉사',
#  '참여',
#  '미용사',
#  '부산',
#  '진구',
#  '서면',
#  '의',
#  '유명',
#  '미용실',
#  '현역',
#  '일',
#  '베테',
#  '평소',
#  '노을',
#  '입',
#  '소문',
#  '환자',
#  '간병',
#  '보호자',
#  '자주',
#  '노을',
#  '맛집',
#  '병원',
#  '옥상',
#  '타코',
#  '맛집',
#  '인기',
#  '끌',
#  '포테토칩',
#  '디스',
#  '타코',
#  '맛',
#  '포테토칩',
#  '소고기',
#  '치즈',
#  '라임',
#  '이브',
#  '홍대',
#  '호점',
#  '부산',
#  '서면',
#  '태화',
#  '점',
#  '대구',
#  '동성로',
#  '점',
#  '총',
#  '곳',
#  '팬미팅',
#  '진행',
#  '예정',
#  '그',
#  '전국',
#  '개',
#  '체인점',
#  '너',
#  '부산',
#  '서면',
#  '위치',
#  '일',
#  '마카',
#  '세',
#  '대표',
#  '대구',
#  '귀신',
#  '짬뽕',
#  '지역',
#  '맛집',
#  '창업',
#  '동문',
#  '활동',
#  '현대',
#  '그린',
#  '푸드',
#  '삼성',
#  '웰스',
#  '토리',
#  '한화',
#  '리조트',
#  '등',
#  '서울',
#  '물회',
#  '맛집',
#  '노량진',
#  '형제',
#  '상회',
#  '강남',
#  '구청',
#  '돌곰',
#  '청담',
#  '한미',
#  '옥',
#  '대치동',
#  '재첩국',
#  '대치',
#  '점',
#  '문래',
#  '깃발',
#  '집',
#  '부산',
#  '서면',
#  '포항',
#  '물',
#  '횟집',
#  '부산',
#  '송도',
#  '횟집',
#  '부산',
#  '광안',
#  '리',
#  '재첩국',
#  '부산',
#  '본점',
#  '부산',
#  '연산',
#  '녹산',
#  '횟집',
#  '번',
#  '완당',
#  '서면',
#  '역',
#  '곳',
#  '위치',
#  '접근성',
#  '가성',
#  '비도',
#  '완당',
#  '판',
#  '모밀',
#  '대표',
#  '테이블',
#  '하나라',
#  '사전',
#  '예약',
#  '글',
#  '사진',
#  '이성',
#  '균',
#  '기자',
#  '부산',
#  '맛집',
#  '부산',
#  '먹거리',
#  '부산',
#  '디저트',
#  '방콕여행',
#  '등',
#  '경품',
#  '혜택',
#  '짐',
#  '층',
#  '놀이',
#  '시설',
#  '등',
#  '재단',
#  '진행',
#  '부산',
#  '대표',
#  '상권',
#  '부산',
#  '진구',
#  '서면',
#  '위치',
#  '오후',
#  '층',
#  '라운지',
#  '파티',
#  '스테이크',
#  '맛집',
#  '신도',
#  '마켓',
#  '이',
#  '황인',
#  '수가',
#  '부산',
#  '광역시',
#  '서면',
#  '직접',
#  '운영',
#  '맛집',
#  '대패',
#  '촬영',
#  '대답',
#  '만',
#  '질문',
#  '다수',
#  '포함',
#  '황',
#  '인수',
#  '명',
#  '만',
#  '킥복싱',
#  '경기',
#  '이후',
#  '시합',
#  '경기',
#  '생',
#  '망고',
#  '개',
#  '일반',
#  '수제',
#  '홀',
#  '케이크',
#  '사이즈',
#  '제품',
#  '온라인',
#  '특급',
#  '호텔',
#  '망고',
#  '프랑',
#  '제리',
#  '망고',
#  '케이크',
#  '판매점',
#  '경기',
#  '평촌',
#  '탑',
#  '부산',
#  '서면',
#  '등',
#  '확대',
#  '계획',
#  '품질',
#  '더',
#  '우리나라',
#  '백화점',
#  '최초',
#  '돼지국밥',
#  '입점',
#  '단숨',
#  '매출',
#  '위',
#  '부산',
#  '서면',
#  '의',
#  '백화점',
#  '층',
#  '식당가',
#  '세계',
#  '역시',
#  '부산',
#  '본점',
#  '복국',
#  '맛집',
#  '복국',
#  '남성',
#  '숙취',
#  '해소',
#  '메뉴',
#  '생각',
#  '오산',
#  '요즘',
#  '인기',
#  '맛집',
#  '금액',
#  '한정',
#  '특가',
#  '마켓',
#  '빅스',
#  '마일',
#  '데이',
#  '마켓',
#  '옥션',
#  '빅스',
#  '마일',
#  '데이',
#  '를',
#  '통해',
#  '부산',
#  '살구',
#  '정원',
#  '롯데',
#  '칠성',
#  '음료',
#  '대표이사',
#  '박윤기',
#  '부산',
#  '서면',
#  '젊음',
#  '거리',
#  '중화요리',
#  '집',
#  '취직',
#  '배달',
#  ...]

# %%
# 집계 데이터 기본 탐색, 모델 구축 하기. 
count = Counter(message_N)
count
# Out:
# Counter({'부산': 914,
#          '서면': 772,
#          '맛집': 668,
#          '점': 352,
#          '등': 270,
#          '곳': 178,
#          '이': 167,
#          '서울': 138,
#          '카페': 134,
#          '지역': 114,
#          '위치': 114,
#          '게임': 101,
#          '오픈': 95,
#          '의': 94,
#          '수': 89,
#          '전국': 89,
#          '대구': 82,
#          '매장': 79,
#          '유명': 74,
#          '상권': 74,
#          '은': 72,
#          '소개': 69,
#          '고객': 67,
#          '홍대': 66,
#          '인기': 64,
#          '층': 64,
#          '주변': 63,
#          '거리': 62,
#          '집': 60,
#          '텔레콤': 60,
#          '진구': 59,
#          '개': 56,
#          '세': 55,
#          '과': 54,
#          '직영': 51,
#          '메뉴': 50,
#          '시장': 49,
#          '대표': 48,
#          '로': 47,
#          '것': 45,
#          '동성로': 45,
#          '대리점': 45,
#          '백화점': 44,
#          '롯데': 44,
#          '로드': 44,
#          '정보': 42,
#          '최근': 42,
#          '밀집': 42,
#          '운영': 42,
#          '보드게임': 42,
#          '이랜드': 40,
#          '타고': 40,
#          '야구': 40,
#          '연습장': 40,
#          '호떡': 39,
#          '맛': 38,
#          '골목': 36,
#          '입': 36,
#          '소문': 36,
#          '제휴': 36,
#          '도': 35,
#          '돼지국밥': 34,
#          '도심': 34,
#          '브랜드': 33,
#          '식당': 33,
#          '관계자': 33,
#          '족발': 32,
#          '지난': 31,
#          '이번': 30,
#          '일례': 30,
#          '시작': 29,
#          '최초': 29,
#          '스시': 28,
#          '쇼핑': 28,
#          '통해': 28,
#          '해운대': 28,
#          '입점': 28,
#          '중': 28,
#          '방송': 28,
#          '도로': 28,
#          '인근': 27,
#          '항': 27,
#          '자리': 26,
#          '사진': 26,
#          '호텔': 26,
#          '팝업': 26,
#          '본점': 25,
#          '달': 25,
#          '오후': 25,
#          '국밥': 25,
#          '더': 25,
#          '베이글': 25,
#          '치킨': 25,
#          '추가': 25,
#          '디저트': 24,
#          '진행': 24,
#          '창업': 24,
#          '역': 24,
#          '저녁': 24,
#          '사람': 24,
#          '를': 23,
#          '강남': 23,
#          '핫': 23,
#          '번화가': 23,
#          '길': 23,
#          '호점': 23,
#          '프로그램': 23,
#          '중심': 23,
#          '손님': 23,
#          '개월': 23,
#          '점주': 23,
#          '위': 22,
#          '포함': 22,
#          '경기': 22,
#          '바': 22,
#          '요리': 22,
#          '이상': 22,
#          '트렌드': 22,
#          '내': 22,
#          '아울렛': 22,
#          '일대': 21,
#          '곱창': 21,
#          '난': 21,
#          '공구': 21,
#          '경북': 21,
#          '직': 21,
#          '공간': 20,
#          '관심': 20,
#          '대전': 20,
#          '그': 20,
#          '친구': 20,
#          '줄': 20,
#          '인천': 20,
#          '전': 20,
#          '광주': 20,
#          '남': 20,
#          '개통': 20,
#          '유동': 20,
#          '매입': 20,
#          '인': 19,
#          '날': 19,
#          '점포': 19,
#          '가격': 19,
#          '시': 19,
#          '광역시': 19,
#          '회': 19,
#          '연': 19,
#          '주요': 19,
#          '문화': 19,
#          '지점': 19,
#          '소': 19,
#          '신세계': 18,
#          '예정': 18,
#          '현재': 18,
#          '가게': 18,
#          '포': 18,
#          '패션': 18,
#          '오늘': 18,
#          '대학로': 18,
#          '충전': 17,
#          '강남역': 16,
#          '제공': 16,
#          '번': 16,
#          '전통': 16,
#          '이태원': 16,
#          '또': 16,
#          '빵': 16,
#          '역시': 16,
#          '문': 16,
#          '인구': 16,
#          '가맹': 16,
#          '외식': 16,
#          '군구': 16,
#          '원동역': 16,
#          '주유소': 16,
#          '생생': 16,
#          '사업': 16,
#          '돼지': 16,
#          '스트릿': 16,
#          '판매': 15,
#          '추천': 15,
#          '송정': 15,
#          '관광객': 15,
#          '이동': 15,
#          '행사': 15,
#          '매출': 15,
#          '앞': 15,
#          '지난해': 15,
#          '여행': 15,
#          '한편': 15,
#          '나': 15,
#          '고': 15,
#          '경우': 15,
#          '구이': 15,
#          '쉐이크': 15,
#          '쉑': 15,
#          '몰이': 15,
#          '그룹': 15,
#          '볼링': 15,
#          '각종': 15,
#          '나이스': 15,
#          '투': 15,
#          '미츄': 15,
#          '편': 14,
#          '및': 14,
#          '방문': 14,
#          '레이스': 14,
#          '커피': 14,
#          '명': 14,
#          '구성': 14,
#          '정도': 14,
#          '팀': 14,
#          '로컬': 14,
#          '영등포': 14,
#          '마산': 14,
#          '차지': 14,
#          '피에스타': 14,
#          '피자': 14,
#          '스타': 13,
#          '대거': 13,
#          '음식': 13,
#          '푸드': 13,
#          '총': 13,
#          '기자': 13,
#          '먹거리': 13,
#          '남포동': 13,
#          '부전동': 13,
#          '계약': 13,
#          '전문점': 13,
#          '떡볶이': 13,
#          '주재': 13,
#          '터널': 13,
#          '광장': 13,
#          '기존': 12,
#          '개발': 12,
#          '위해': 12,
#          '관': 12,
#          '씨': 12,
#          '가지': 12,
#          '외국인': 12,
#          '국내': 12,
#          '음식점': 12,
#          '통닭': 12,
#          '프랜차이즈': 12,
#          '분위기': 12,
#          '전남대': 12,
#          '가로수길': 12,
#          '병점': 12,
#          '황제': 12,
#          '장소': 11,
#          '이후': 11,
#          '비롯': 11,
#          '여러': 11,
#          '관광': 11,
#          '할인': 11,
#          '직접': 11,
#          '사이': 11,
#          '대형': 11,
#          '식사': 11,
#          '마포': 11,
#          '설명': 11,
#          '볼': 11,
#          '초': 11,
#          '미헌': 11,
#          '영업': 11,
#          '갈비': 11,
#          '우리': 11,
#          '월드': 11,
#          '가장': 11,
#          '가포': 11,
#          '신설': 11,
#          '연결': 11,
#          '첫': 11,
#          '소비자': 10,
#          '밥': 10,
#          '명소': 10,
#          '혜택': 10,
#          '온라인': 10,
#          '이름': 10,
#          '고기': 10,
#          '중이': 10,
#          '각각': 10,
#          '김밥': 10,
#          '원': 10,
#          '백반': 10,
#          '부전': 10,
#          '밀면': 10,
#          '탐방': 10,
#          '보쌈': 10,
#          '해': 10,
#          '준비': 10,
#          '주목': 10,
#          '번길': 10,
#          '평': 10,
#          '생방송': 10,
#          '비': 10,
#          '또한': 10,
#          '교통': 10,
#          '감자탕': 10,
#          '생생정보통': 10,
#          '매콤': 10,
#          '전골': 10,
#          '가운데': 10,
#          '팝': 10,
#          '이벤트': 10,
#          '협업': 9,
#          '상품': 9,
#          '시민': 9,
#          '개점': 9,
#          '신촌': 9,
#          '대한': 9,
#          '시간': 9,
#          '온': 9,
#          '최대': 9,
#          '이전': 9,
#          '참여': 9,
#          '업체': 9,
#          '리': 9,
#          '일': 9,
#          '평소': 9,
#          '병원': 9,
#          '짐': 9,
#          '마켓': 9,
#          '인생': 9,
#          '돈까스': 9,
#          '코너': 9,
#          '얼': 9,
#          '돼지고기': 9,
#          '파스타': 9,
#          '말': 9,
#          '모두': 9,
#          '코스': 9,
#          '주소': 9,
#          '레스토랑': 9,
#          '대박': 9,
#          '비밀': 9,
#          '최고': 9,
#          '한우': 9,
#          '꼭': 9,
#          '포인트': 9,
#          '초밥': 9,
#          '김포': 9,
#          '진': 9,
#          '누룽지': 9,
#          '국수': 9,
#          '살': 9,
#          '바로': 9,
#          '백종원': 9,
#          '냉칼국수': 9,
#          '사우': 9,
#          '잠수함': 9,
#          '해당': 8,
#          '전문': 8,
#          '잡고': 8,
#          '마카': 8,
#          '프리미엄': 8,
#          '광안': 8,
#          '특화': 8,
#          '쿠팡': 8,
#          '물': 8,
#          '생': 8,
#          '제': 8,
#          '명품': 8,
#          '스토어': 8,
#          '남녀': 8,
#          '몸': 8,
#          '재료': 8,
#          '올해': 8,
#          '한국': 8,
#          '제한': 8,
#          '향': 8,
#          '여개': 8,
#          '서비스': 8,
#          '뿐': 8,
#          '문의': 8,
#          '모습': 8,
#          '칼국수': 8,
#          '평택': 8,
#          '때문': 8,
#          '발': 8,
#          '간식': 8,
#          '햄버거': 8,
#          '방침': 8,
#          '그대로': 8,
#          '하나': 8,
#          '불고기': 8,
#          '비중': 8,
#          '대상': 8,
#          '한명진': 8,
#          '앨리': 8,
#          '술집': 8,
#          '해산물': 8,
#          '역점': 8,
#          '화성': 8,
#          '블로그': 8,
#          '철권': 8,
#          '반값': 8,
#          '일본': 7,
#          '이색': 7,
#          '오프라인': 7,
#          '후기': 7,
#          '중앙': 7,
#          '상가': 7,
#          '김해': 7,
#          '이자': 7,
#          '분식': 7,
#          '지금': 7,
#          '현장': 7,
#          '명동': 7,
#          '코로나': 7,
#          '수원': 7,
#          '츠': 7,
#          '동래': 7,
#          '제리': 7,
#          '자주': 7,
#          '케이크': 7,
#          '젊음': 7,
#          '근처': 7,
#          '끼': 7,
#          '호선': 7,
#          '베이커리': 7,
#          '딸기': 7,
#          '무엇': 7,
#          '영국': 7,
#          '계속': 7,
#          '도전': 7,
#          '속': 7,
#          '고깃집': 7,
#          '전포동': 7,
#          '이나': 7,
#          '황령산': 7,
#          '봉수대': 7,
#          '울산': 7,
#          '제주': 7,
#          '갈비탕': 7,
#          '원조': 7,
#          '마카롱': 7,
#          '사랑': 7,
#          '마': 7,
#          '호평': 7,
#          '메뉴인': 7,
#          '지원': 7,
#          '업계': 7,
#          '마스': 7,
#          '여': 7,
#          '수도권': 7,
#          '갤러리아': 7,
#          '선정': 7,
#          '분홍색': 7,
#          '지하철': 7,
#          '화산': 7,
#          '개미': 7,
#          '복합': 7,
#          '대학생': 7,
#          '오락': 7,
#          '영향': 7,
#          '찜': 7,
#          '연어': 7,
#          '맥주': 7,
#          '까페': 7,
#          '랍': 7,
#          '일산': 7,
#          '안': 7,
#          '페이스북': 7,
#          '계대': 7,
#          '구미': 7,
#          '페스': 7,
#          '타점': 7,
#          '둔산': 7,
#          '빠담빠담': 7,
#          '제품': 6,
#          '숍': 6,
#          '이용': 6,
#          '해외': 6,
#          '신규': 6,
#          '센텀시티': 6,
#          '수제': 6,
#          '버거': 6,
#          '다른': 6,
#          '리점': 6,
#          '노을': 6,
#          '태화': 6,
#          '체인점': 6,
#          '형제': 6,
#          '세계': 6,
#          '식품': 6,
#          '건물': 6,
#          '아이스크림': 6,
#          '여름': 6,
#          '사장': 6,
#          '구월동': 6,
#          '풀': 6,
#          '식': 6,
#          '체험': 6,
#          '직장인': 6,
#          '주인': 6,
#          '뽈탕': 6,
#          '눈길': 6,
#          '정점': 6,
#          '마케팅': 6,
#          '곳곳': 6,
#          '기행': 6,
#          '검색': 6,
#          '때': 6,
#          '지방': 6,
#          '인테리어': 6,
#          '순대': 6,
#          '간편식': 6,
#          '데': 6,
#          '만큼': 6,
#          '발길': 6,
#          '낙지': 6,
#          '캐치': 6,
#          '산이': 6,
#          '초성': 6,
#          '시식': 6,
#          '우영은': 6,
#          '젊은이': 6,
#          '증가': 6,
#          '양옥': 6,
#          '두': 6,
#          '여기': 6,
#          '천년': 6,
#          '하트': 6,
#          '모양': 6,
#          '볼거리': 6,
#          '성공': 6,
#          '야채': 6,
#          '장기': 6,
#          '새우': 6,
#          '삼정': 6,
#          '숙성': 6,
#          '이탈리아': 6,
#          '향후': 6,
#          '영화관': 6,
#          '입맛': 6,
#          '해운대해수욕장': 6,
#          '동백섬': 6,
#          '바토': 6,
#          '레쿠': 6,
#          '오모': 6,
#          '하나로': 6,
#          '인동': 6,
#          '상세': 6,
#          '샐러드': 6,
#          '애슐리': 6,
#          '애니플러스': 5,
#          '일상': 5,
#          '마련': 5,
#          '필드': 5,
#          '소품': 5,
#          '커뮤니티': 5,
#          '계획': 5,
#          '검증': 5,
#          '셰프': 5,
#          '실제': 5,
#          '기념': 5,
#          '듯': 5,
#          '성수동': 5,
#          '시내': 5,
#          '밀': 5,
#          '모루': 5,
#          '끌': 5,
#          '소고기': 5,
#          '치즈': 5,
#          '송도': 5,
#          '테이블': 5,
#          '예약': 5,
#          '글': 5,
#          '놀이': 5,
#          '스테이크': 5,
#          '촬영': 5,
#          '만': 5,
#          '확대': 5,
#          '생각': 5,
#          '요즘': 5,
#          '배달': 5,
#          '정': 5,
#          '변신': 5,
#          '활용': 5,
#          '마트': 5,
#          '공사': 5,
#          '시청': 5,
#          '쌍둥이': 5,
#          '라면': 5,
#          '도시': 5,
#          '강': 5,
#          '처': 5,
#          '감성': 5,
#          '비주': 5,
#          '탄생': 5,
#          '브런치': 5,
#          '처음': 5,
#          '복': 5,
#          '연포탕': 5,
#          '보쌈김치': 5,
#          '직원': 5,
#          '중심지': 5,
#          '인터넷': 5,
#          '입지': 5,
#          '광안대교': 5,
#          '한눈': 5,
#          '조': 5,
#          '마음': 5,
#          '경남': 5,
#          '컬리': 5,
#          '크게': 5,
#          '당시': 5,
#          '반응': 5,
#          '북적': 5,
#          '퓨전': 5,
#          '생활': 5,
#          '마지막': 5,
#          '옆': 5,
#          '주': 5,
#          '후': 5,
#          '방': 5,
#          '하루': 5,
#          '끼리': 5,
#          '동시': 5,
#          '싸이': 5,
#          '라잇': 5,
#          '나우': 5,
#          '캡처': 5,
#          '매일': 5,
#          '종': 5,
#          '주점': 5,
#          '미식': 5,
#          '빼': 5,
#          '타임': 5,
#          '중인': 5,
#          '기도': 5,
#          '개설': 5,
#          '용인': 5,
#          '세브란스': 5,
#          '국물': 5,
#          '닭': 5,
#          '경산': 5,
#          '콘텐츠': 5,
#          '연희': 5,
#          '수호': 5,
#          '스페셜': 5,
#          '가상현실': 5,
#          '다음': 5,
#          '화공': 5,
#          '그랜드': 5,
#          '아웃백': 5,
#          '스테이크하우스': 5,
#          '다리': 5,
#          '트럭': 5,
#          '조리': 5,
#          '뷔페': 5,
#          '육개장': 5,
#          '곰탕': 5,
#          '본연': 5,
#          '방향': 5,
#          '펍': 5,
#          '시가지': 5,
#          '눈': 5,
#          '연구': 5,
#          '김치': 5,
#          '삼겹살': 5,
#          '유통': 5,
#          '대중매체': 5,
#          '트랜드': 5,
#          '일원': 5,
#          '토마토': 5,
#          '테이스티로드': 5,
#          '뉴스': 5,
#          '여수': 5,
#          '공항': 5,
#          '아웃렛': 5,
#          '해물찜': 5,
#          '멤버십': 5,
#          '발굴': 4,
#          '린': 4,
#          '차': 4,
#          '국제': 4,
#          '건너편': 4,
#          '투어': 4,
#          '편의': 4,
#          '샤': 4,
#          '인파': 4,
#          '호응': 4,
#          '축제': 4,
#          '분당': 4,
#          '과자': 4,
#          '쇼': 4,
#          '줌': 4,
#          '남천동': 4,
#          '무슈': 4,
#          '뱅': 4,
#          '아티': 4,
#          '블렁': 4,
#          '빵빵': 4,
#          '빵집': 4,
#          '현대': 4,
#          '토리': 4,
#          '옥': 4,
#          '포항': 4,
#          '횟집': 4,
#          '시설': 4,
#          '망고': 4,
#          '한정': 4,
#          '데이': 4,
#          '블루': 4,
#          '광교': 4,
#          '전역': 4,
#          '아침': 4,
#          '요소': 4,
#          '지도': 4,
#          '범일': 4,
#          '영도': 4,
#          '공식': 4,
#          '트렌디': 4,
#          '서서': 4,
#          '며': 4,
#          '심지어': 4,
#          '뽈': 4,
#          '화제': 4,
#          '합': 4,
#          '각': 4,
#          '켈리': 4,
#          '미성년': 4,
#          '출입': 4,
#          '안주': 4,
#          '홍': 4,
#          '콤': 4,
#          '게': 4,
#          '산업': 4,
#          '하이': 4,
#          '윤': 4,
#          '지고': 4,
#          '진가': 4,
#          '퇴근': 4,
#          '주문': 4,
#          '거듭': 4,
#          '주말': 4,
#          '제외': 4,
#          '손': 4,
#          '앞서': 4,
#          '뒷골목': 4,
#          '평일': 4,
#          '불': 4,
#          '압구정': 4,
#          '규모': 4,
#          '개성': 4,
#          '타르트': 4,
#          '자랑': 4,
#          '세대': 4,
#          '평균': 4,
#          '번가': 4,
#          '뒤': 4,
#          '우대': 4,
#          '권': 4,
#          '통': 4,
#          '집중': 4,
#          '이마트': 4,
#          '로서': 4,
#          '패밀리': 4,
#          '천왕': 4,
#          '오이': 4,
#          '여성': 4,
#          '지하': 4,
#          '외': 4,
#          '타워': 4,
#          '튀김': 4,
#          '핵심': 4,
#          '분야': 4,
#          '아세안': 4,
#          '스트리트': 4,
#          '지구': 4,
#          '점도': 4,
#          '출구': 4,
#          '동안': 4,
#          '드라마': 4,
#          '미국': 4,
#          '지번': 4,
#          '월': 4,
#          '양': 4,
#          '이야기': 4,
#          '목표': 4,
#          '데이트': 4,
#          '조개찜': 4,
#          '부활': 4,
#          '타르': 4,
#          '이제': 4,
#          '경쟁력': 4,
#          '연수': 4,
#          '교점': 4,
#          '츄러스': 4,
#          '다리미': 4,
#          '포차': 4,
#          '율하점': 4,
#          '주부': 4,
#          '퀸즈': 4,
#          '일식': 3,
#          '스낵바': 3,
#          '강릉': 3,
#          '가입': 3,
#          '경험': 3,
#          '느낌': 3,
#          '역할': 3,
#          '상공': 3,
#          '소상': 3,
#          '공인': 3,
#          '간의': 3,
#          '활성화': 3,
#          '라며': 3,
#          '오피스': 3,
#          '콘셉트': 3,
#          '차별': 3,
#          '라멘': 3,
#          '송': 3,
#          '미용': 3,
#          '봉사': 3,
#          '미용사': 3,
#          '미용실': 3,
#          '현역': 3,
#          '베테': 3,
#          '환자': 3,
#          '간병': 3,
#          '보호자': 3,
#          '이브': 3,
#          '짬뽕': 3,
#          '가성': 3,
#          '이성': 3,
#          '일반': 3,
#          '프랑': 3,
#          '복국': 3,
#          '음료': 3,
#          '한식': 3,
#          '거제': 3,
#          '적용': 3,
#          '통한': 3,
#          '호': 3,
#          '명성': 3,
#          '양식': 3,
#          '댄스': 3,
#          '관람객': 3,
#          '루지': 3,
#          '바이애슬론': 3,
#          '관람': 3,
#          '북부': 3,
#          '로데오거리': 3,
#          '폐업': 3,
#          '선택': 3,
#          '김': 3,
#          '하동관': 3,
#          '인사동': 3,
#          '설렁탕': 3,
#          '무교': 3,
#          '동북': 3,
#          '국집': 3,
#          '용두동': 3,
#          '어머니': 3,
#          '대성': 3,
#          '각자': 3,
#          '사례': 3,
#          '면세점': 3,
#          '사용': 3,
#          '정식': 3,
#          '출시': 3,
#          '떡': 3,
#          '단일': 3,
#          '선물': 3,
#          '세트': 3,
#          '구성은': 3,
#          '산': 3,
#          '센터': 3,
#          '발생': 3,
#          '강석우': 3,
#          '종점': 3,
#          '주년': 3,
#          '어디': 3,
#          '터': 3,
#          '상': 3,
#          '송파': 3,
#          '논현': 3,
#          '배경': 3,
#          '얘기': 3,
#          '천안': 3,
#          '의미': 3,
#          '공원': 3,
#          '메이': 3,
#          '주간': 3,
#          '진영': 3,
#          '비법': 3,
#          '자연': 3,
#          '공격': 3,
#          '상무지구': 3,
#          '분석': 3,
#          '춘하': 3,
#          '추': 3,
#          '업자': 3,
#          '랭킹': 3,
#          '한식당': 3,
#          '쇼핑몰': 3,
#          '인분': 3,
#          '닭갈비': 3,
#          '경기도': 3,
#          '실': 3,
#          '조개': 3,
#          '이대': 3,
#          '인식': 3,
#          '치': 3,
#          '마포구': 3,
#          '양산도': 3,
#          '민물장어': 3,
#          '유통업': 3,
#          '기획': 3,
#          '한창': 3,
#          '남부': 3,
#          '불구': 3,
#          '홈페이지': 3,
#          '보': 3,
#          '금강': 3,
#          '충장로': 3,
#          '남동구': 3,
#          '달인': 3,
#          '인스타그램': 3,
#          '학교': 3,
#          '밤': 3,
#          '바비큐': 3,
#          '봄': 3,
#          '특별': 3,
#          '티': 3,
#          '연휴': 3,
#          '상인': 3,
#          '신흥': 3,
#          '경성대': 3,
#          '돌': 3,
#          '랜드마크': 3,
#          '샌드위치': 3,
#          '자신': 3,
#          '단': 3,
#          '북': 3,
#          '구점': 3,
#          '현지': 3,
#          '밥집': 3,
#          '공장': 3,
#          '등장': 3,
#          '관계': 3,
#          '광복동': 3,
#          '스페인': 3,
#          '부': 3,
#          '더욱': 3,
#          '마루': 3,
#          '진짜': 3,
#          '탕': 3,
#          '키친': 3,
#          '초량': 3,
#          '상무': 3,
#          '프로젝트': 3,
#          '동네': 3,
#          '미디어': 3,
#          '기': 3,
#          '수육': 3,
#          '리지': 3,
#          '예': 3,
#          '무료': 3,
#          '대창': 3,
#          '대중교통': 3,
#          '도보': 3,
#          '오전': 3,
#          '오리': 3,
#          '네이버': 3,
#          '반영': 3,
#          '특색': 3,
#          '장작': 3,
#          '이상화': 3,
#          '당일': 3,
#          '출연': 3,
#          '형태': 3,
#          '조성': 3,
#          '면': 3,
#          '고향': 3,
#          '인정': 3,
#          '먼저': 3,
#          '단장': 3,
#          '채': 3,
#          '몇': 3,
#          '단골': 3,
#          '가마솥': 3,
#          '회식': 3,
#          '체부동': 3,
#          '참치회': 3,
#          '부추': 3,
#          '만족': 3,
#          '어쭈': 3,
#          '쭈꾸미': 3,
#          '소용돌이': 3,
#          '특유': 3,
#          '우동': 3,
#          '마니아': 3,
#          '가의': 3,
#          '이미지': 3,
#          '소스': 3,
#          '칼질': 3,
#          '생물': 3,
#          ...})

# %%
# 임시 딕션너리에 담아서, 필요한 부분 추출해서 조사. 
word_count = dict()

# 상위 80개 정도 
for tag, counts in count.most_common(80):
  if(len(str(tag))>1):
    word_count[tag] = counts
    # print(f" tag : {tag}, counts : {counts}")
word_count
# Out:
# {'부산': 914,
#  '서면': 772,
#  '맛집': 668,
#  '서울': 138,
#  '카페': 134,
#  '지역': 114,
#  '위치': 114,
#  '게임': 101,
#  '오픈': 95,
#  '전국': 89,
#  '대구': 82,
#  '매장': 79,
#  '유명': 74,
#  '상권': 74,
#  '소개': 69,
#  '고객': 67,
#  '홍대': 66,
#  '인기': 64,
#  '주변': 63,
#  '거리': 62,
#  '텔레콤': 60,
#  '진구': 59,
#  '직영': 51,
#  '메뉴': 50,
#  '시장': 49,
#  '대표': 48,
#  '동성로': 45,
#  '대리점': 45,
#  '백화점': 44,
#  '롯데': 44,
#  '로드': 44,
#  '정보': 42,
#  '최근': 42,
#  '밀집': 42,
#  '운영': 42,
#  '보드게임': 42,
#  '이랜드': 40,
#  '타고': 40,
#  '야구': 40,
#  '연습장': 40,
#  '호떡': 39,
#  '골목': 36,
#  '소문': 36,
#  '제휴': 36,
#  '돼지국밥': 34,
#  '도심': 34,
#  '브랜드': 33,
#  '식당': 33,
#  '관계자': 33,
#  '족발': 32,
#  '지난': 31,
#  '이번': 30,
#  '일례': 30,
#  '시작': 29,
#  '최초': 29,
#  '스시': 28,
#  '쇼핑': 28,
#  '통해': 28,
#  '해운대': 28,
#  '입점': 28,
#  '방송': 28,
#  '도로': 28}

# %%
# 시각화1, 막대 그래프 
# 폰트 임포트 , 메모리에 설정 
font_path = "c:/Windows/Fonts/malgunbd.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rc("font", family = font_name)

#, x축, y축, 가로x세로 비율, x 라벨, 폰트 설정 등
plt.figure(figsize=(12,6))
plt.xlabel("키워드")
plt.ylabel("빈도수")
plt.grid(True)

# 딕션너리의 키, 값 , 정렬 내림차순 
sorted_Keys = sorted(word_count, key=word_count.get, reverse=True)
sorted_Values = sorted(word_count.values(),reverse=True)

# 막대 그래프 그리기. 
plt.bar(range(len(word_count)), sorted_Values, align="center")

# x 축 라벨 설정. 
plt.xticks(range(len(word_count)), list(sorted_Keys), rotation = "vertical")

plt.show()

# %%
# !pip install Numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: Numpy in c:\users\it\appdata\roaming\python\python310\site-packages (1.26.4)
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# 시각화2, 워드 클라우드 
import numpy as np

import os
import re
from PIL import Image
from os import path

alice_mask = np.array(Image.open("dog-test2.png"))

# 실행시, 한글이 깨져서, 해당 폰트 패스 경로 지정 필요.
wc = WordCloud(font_path, background_color="white", max_words=1000, mask=alice_mask,width=800,height=1000)
# generate word cloud
sampleImage = wc.generate_from_frequencies(word_count)

# show
plt.imshow(sampleImage, interpolation="bilinear")
# plt.imshow(sampleImage)

plt.axis("off")
plt.show()

# %%
# 해당 출력을 이미지로 저장 하기. 
sampleImage.to_file(inputFileName + "_cloud.jpg")
